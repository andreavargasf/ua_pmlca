# %% [markdown]
# # Exchanges exploration

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pprint import pprint

import bw2analyzer as bwa
import bw2calc as bc
import bw2data as bd
import bw2io as bi
import bw_processing as bwp
import numpy as np

# import ipywidgets as widgets
import pandas as pd
from bw2data.query import Filter, Query
from IPython.display import display
from tqdm import autonotebook

# %%
from project_details import EI_DB_NAME, PROJECT_NAME

# %%
bd.projects.set_current(PROJECT_NAME)
bd.databases
# Out:
# Databases dictionary with 3 object(s):
# 	asphalt
# 	biosphere3
# 	ecoinvent-391-cutoff

# %%
# Is the background database name the same as the one we wrote in `propject_details.py`?
assert EI_DB_NAME in bd.databases

# %%
FG_DB_NAME = "asphalt"

# %%
db_asphalt = bd.Database(FG_DB_NAME)

# %%
pavement_complete_a = db_asphalt.get("DZOAB, A")
pavement_complete_a_PVI = db_asphalt.get("DZOAB, A, PVI")
pavement_complete_b = db_asphalt.get("DZOAB, B")
pavement_complete_b_PVI = db_asphalt.get("DZOAB, B, PVI")

# %%
bwa.print_recursive_supply_chain(pavement_complete_a_PVI, max_level=1)
# Out:
# 1: 'DZOAB, A, PVI' (kilogram, NL, None)
#   1: 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)
#   1: 'A1, pavement, materials, A (own material)' (kilogram, NL, None)
#   1: 'A2, pavement, transport to plant, A (bitumen)' (kilogram, NL, None)
#   1: 'A2, pavement, transport to plant, A (crushed stone)' (kilogram, NL, None)
#   1: 'A2, pavement, transport to plant, A (own material)' (kilogram, NL, None)
#   1: 'A2, pavement, transport to plant, A (crushed sand)' (kilogram, NL, None)
#   1: 'A2, pavement, transport to plant, A (drip resistant material)' (kilogram, NL, None)
#   1: 'A2, pavement, transport to plant, A (filler)' (kilogram, NL, None)
#   1: 'A3, pavement, production, A' (kilogram, NL, None)
#   1: 'A4, pavement, transport to site' (kilogram, NL, None)
#   1: 'A5, pavement, construction' (kilogram, NL, None)
#   1: 'B, pavement, use (car and HDV)' (kilogram, NL, None)
#   1: 'B, pavement, use (HDV+)' (kilogram, NL, None)
#   1: 'C1, pavement, demolition' (kilogram, NL, None)
#   1: 'C2, pavement, transport to processing' (kilogram, NL, None)
#   1: 'C3, pavement, processing (crane and shovel)' (kilogram, NL, None)
#   1: 'C3, pavement, processing (breaking)' (kilogram, NL, None)

# %% [markdown]
# ## Associate exchanges to samples
#
# ### Work with the pavement materials
#
# First let's verify that we can use the information already contained in the db.
#
# The excel file for the foreground provides a comments field that gives a generic name of the exchange. This can be linked to the name of the column of the generated samples.

# %% [markdown]
# Let's first look at the pavement materials data to create the data structures that we could use later with data packages.

# %%
db_asphalt.search('A1, materials (excl. own material)')[0].as_dict()
# Out:
# {'reference product': 'A1, pavement, materials (excl. own material)',
#  'code': 'A1_materials_A_excl.ownmaterial',
#  'location': 'NL',
#  'amount': 1,
#  'unit': 'kilogram',
#  'original_ConversionDem2FU': 1,
#  'name': 'A1, pavement, materials, A (excl. own material)',
#  'worksheet name': 'Sheet1',
#  'database': 'asphalt',
#  'id': 25987}

# %%
pavement_mats = bd.get_activity(25987)
print(pavement_mats)
# Out:
# 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)

# %%
for e in pavement_mats.technosphere():
    print(e)
# Out:
# Exchange: 0.3 kilogram 'asphalt granulate, free of burden' (kilogram, NL, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# Exchange: 0.0412 kilogram 'bitumen adhesive compound production, hot' (kilogram, RER, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# Exchange: 0.5861000000000001 kilogram 'crushed stone, from quarry in Europe, excluding transport to the Netherlands' (kilogram, NL, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# Exchange: 0.0342 kilogram 'gravel production, crushed' (kilogram, RoW, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# Exchange: 0.0021000000000000003 kilogram 'cellulose fibre production (without borax and boric acid)' (kilogram, RoW, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# Exchange: 0.027 kilogram 'medium filler' (kilogram, NL, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>

# %%
#detail look to exchanges of interest
[exc for exc in pavement_mats.technosphere()][2].as_dict()
# Out:
# {'name': 'crushed stone, from quarry in Europe, excluding transport to the Netherlands',
#  'reference product': 'crushed stone',
#  'location': 'NL',
#  'amount': 0.5861000000000001,
#  'unit': 'kilogram',
#  'database': 'ecoinvent-391-cutoff',
#  'type': 'technosphere',
#  'categories': ('(unknown)',),
#  'comments': 'crushed stone',
#  'uncertainty_type': 2,
#  'loc': -0.5342648554997534,
#  'scale': 0.03741657386773941,
#  'input': ('asphalt', 'crushed_stone'),
#  'output': ('asphalt', 'A1_materials_A_excl.ownmaterial')}

# %% [markdown]
# The exchanges include a "comments" field

# %%
for e in pavement_mats.technosphere():
    if "comments" in e.as_dict():
        # print(e["comments"])
        pprint(e["comments"])
# Out:
# 'rap'
# 'bitumen'
# 'crushed stone'
# 'crushed sand'
# 'drip resistant material'
# 'filler'

# %%
def exchange_coords(exchange):
    """create a tuple with the numerical ids of the input and output activites of an exchange."""
    input_activity = bd.get_activity(exchange["input"])
    output_activity = bd.get_activity(exchange["output"])
    return (input_activity.id, output_activity.id)

# %%
# We can create tuples of coords for every non "production" exchange of an activity like this.
for e in pavement_mats.technosphere():
    print(exchange_coords(e))
# Out:
# (25975, 25987)
# (8553, 25987)
# (25976, 25987)
# (17503, 25987)
# (25974, 25987)
# (25977, 25987)

# %% [markdown]
# ### Parse all the pre-generated samples.

# %%
samples_df = pd.read_excel(
    "Final_samples.xlsx", sheet_name=pavement_complete_a["name"], dtype=float, index_col=0
)
samples_df.head()
# Out:
#    A1_bitumen  A1_crushedsand  A1_crushedstone3  A1_asphaltgranulate  \
# 0    0.042558        0.035116          0.591192             0.299967
# 1    0.039691        0.032146          0.577359             0.327039
# 2    0.040694        0.035285          0.579170             0.300157
# 3    0.040881        0.035088          0.572281             0.288649
# 4    0.040095        0.035370          0.572222             0.332977
#
#    A1_ownmaterial  A1_mediumfiller  A1_dripresistantmaterial  A2_bitumen  \
# 0        0.009732         0.025648                  0.002002    0.009872
# 1        0.009244         0.028904                  0.002002    0.011234
# 2        0.009573         0.027313                  0.002013    0.012900
# 3        0.009698         0.027617                  0.002028    0.012794
# 4        0.009691         0.025722                  0.002132    0.011271
#
#    A2_crushedsand_t  A2_crushedsand_iv  ...  A3_electricity  A3_diesel  \
# 0          0.000902           0.028033  ...        0.005639   0.003824
# 1          0.000900           0.014003  ...        0.006124   0.003739
# 2          0.001119           0.046039  ...        0.005531   0.003930
# 3          0.000880           0.019909  ...        0.005544   0.003700
# 4          0.001263           0.027920  ...        0.006050   0.003761
#
#    A4_distance_EURO5  A4_distance_EURO6  A5_construction  C1_removal  \
# 0           0.023854           0.007951         0.009716    0.024317
# 1           0.036901           0.012300         0.010399    0.025039
# 2           0.023517           0.007839         0.010004    0.023950
# 3           0.034301           0.011434         0.009605    0.023829
# 4           0.044652           0.014884         0.010502    0.024140
#
#    C2_distance_EURO5  C2_distance_EURO6  C3_craneandshovel  C3_breaker
# 0           0.035624           0.011875           0.006003    0.005458
# 1           0.022755           0.007585           0.006007    0.006206
# 2           0.023741           0.007914           0.005880    0.006016
# 3           0.019934           0.006645           0.005800    0.005765
# 4           0.048939           0.016313           0.005469    0.005981
#
# [5 rows x 28 columns]

# %%
samples_df.columns
# Out:
# Index(['A1_bitumen', 'A1_crushedsand', 'A1_crushedstone3',
#        'A1_asphaltgranulate', 'A1_ownmaterial', 'A1_mediumfiller',
#        'A1_dripresistantmaterial', 'A2_bitumen', 'A2_crushedsand_t',
#        'A2_crushedsand_iv', 'A2_crushedstone3_t', 'A2_crushedstone3_iv',
#        'A2_crushedstone3_sv', 'A2_ownmaterial_t', 'A2_ownmaterial_iv',
#        'A2_mediumfiller', 'A2_dripresistantmaterial', 'A3_naturalgas',
#        'A3_electricity', 'A3_diesel', 'A4_distance_EURO5', 'A4_distance_EURO6',
#        'A5_construction', 'C1_removal', 'C2_distance_EURO5',
#        'C2_distance_EURO6', 'C3_craneandshovel', 'C3_breaker'],
#       dtype='object')

# %% [markdown]
# Each sample column is meant to be associated to one phase (A1, A2, etc.) and an inputs of a pavement exchange.
# We can map the comment of the exchange to an existing samples column name roughly like this:

# %%
def sample_name_for_exchange(exchange, phase):
    """Return the sample name to use for this exchange."""
    all_names_mapping = {
        "A1": {
            "bitumen": "A1_bitumen",
            "crushed sand": "A1_crushedsand",
            "crushed stone": "A1_crushedstone3",
            "rap": "A1_asphaltgranulate",
            "own material": "A1_ownmaterial",
            "filler": "A1_mediumfiller",
            "drip resistant material": "A1_dripresistantmaterial",
        },
        "A2": {
            "bitumen": "A2_bitumen",
            "filler": "A2_mediumfiller",
            "drip resistant material": "A2_dripresistantmaterial",
        },
    }

    if "A1" == phase:
        names_mapping = all_names_mapping[phase]
        col_name = names_mapping[exchange["comments"]]
    if "A2" == phase:
        names_mapping = all_names_mapping[phase]
        if exchange["comments"] in names_mapping:
            return names_mapping[exchange["comments"]]
        else:
            input_activity = bd.get_activity(exchange["input"])
            comments = exchange["comments"]
            var_name = exchange["comments"].replace(" ", "")
            if var_name == "crushedstone":
                var_name = var_name + "3"
            ref_prod = input_activity["reference product"]
            if ref_prod == "transport, freight, sea, ferry":
                suffix = "sv"
            if ref_prod == "transport, freight, inland waterways, barge":
                suffix = "iv"
            if ref_prod == "transport, freight, lorry, unspecified":
                suffix = "t"
            col_name = f"{phase}_{var_name}_{suffix}"
    if "A3" == phase:
        input_activity = bd.get_activity(exchange["input"])
        ref_prod = input_activity["reference product"]
        if ref_prod == "electricity, low voltage":
            col_name = f"{phase}_electricity"
        elif ref_prod == "heat, district or industrial, natural gas":
            col_name = f"{phase}_naturalgas"
        elif ref_prod == "diesel, burned in building machine":
            col_name = f"{phase}_diesel"
    if "A4" == phase or "C2" == phase:
        input_activity = bd.get_activity(exchange["input"])
        comments = exchange["comments"]
        if comments == "EURO5":
            col_name = f"{phase}_distance_EURO5"
        elif comments == "EURO6":
            col_name = f"{phase}_distance_EURO6"
    if "A5" == phase:
        col_name = f"{phase}_construction"
    if "B" == phase:
        input_activity = bd.get_activity(exchange["input"])
        comments = exchange["comments"]
        if comments == "car":
            col_name = f"{phase}_cars_avg"
        elif comments == "HDV":
            col_name = f"{phase}_HDV_avg"
        elif comments == "HDV+":
            col_name = f"{phase}_HDVtrailer_avg"
    if "C1" == phase:
        col_name = f"{phase}_removal"
    if "C3" == phase:
        input_activity = bd.get_activity(exchange["input"])
        comments = exchange["comments"]
        if comments == "shovel":
            col_name = f"{phase}_craneandshovel"
        elif comments == "breaking":
            col_name = f"{phase}_breaker"

    return col_name

# %%
def build_coords_sample(activity, samples_df):
    """Build the coords + sample dictionnary for all phases of activity.

    The activities are the top level "pavement complete" producing ones:

    [0]: DZOAB, A, PVI (pavement, complete, NL)
    [1]: DZOAB, B, PVI (pavement, complete, NL)
    [2]: DZOAB, B (pavement, complete, NL)
    [3]: DZOAB, A (pavement, complete, NL)

    """
    # Make sure we have a valid activity to start with
    assert "pavement, complete" == activity["reference product"]
    coords_samples_map = {}

    # the phases are for example: A1, pavement, materials, A
    # We must create the coords_sample for the inputs of each "phase"
    phase_exchanges = [input for input in activity.technosphere()]
    counter = 0
    for phase_exchange in phase_exchanges:
        input_activity = bd.get_activity(phase_exchange["input"])
        # pprint(input_activity)
        # mapping = build_mapping(input_activity)
        # print(mapping)
        # Extract the "A1", "A2", etc. substring from the phase name
        current_phase = input_activity["name"].split(",")[0]
        for exchange in input_activity.technosphere():
            col_name = sample_name_for_exchange(exchange, current_phase)
            coords = exchange_coords(exchange)
            counter += 1
            print(f"{counter}. {exchange}\n\t 👉 {coords} to {col_name}")
            coords_samples_map[exchange_coords(exchange)] = samples_df[
                col_name
            ].values  # numpy.ndarray
    return coords_samples_map

# %%
# This is how to build the coords_samples_map for the full pavement activity
coords_samples_map = build_coords_sample(pavement_complete_a, samples_df)
# Out:
# 1. Exchange: 0.3 kilogram 'asphalt granulate, free of burden' (kilogram, NL, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# 	 👉 (25975, 25987) to A1_asphaltgranulate
# 2. Exchange: 0.0412 kilogram 'bitumen adhesive compound production, hot' (kilogram, RER, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# 	 👉 (8553, 25987) to A1_bitumen
# 3. Exchange: 0.5861000000000001 kilogram 'crushed stone, from quarry in Europe, excluding transport to the Netherlands' (kilogram, NL, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# 	 👉 (25976, 25987) to A1_crushedstone3
# 4. Exchange: 0.0342 kilogram 'gravel production, crushed' (kilogram, RoW, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# 	 👉 (17503, 25987) to A1_crushedsand
# 5. Exchange: 0.0021000000000000003 kilogram 'cellulose fibre production (without borax and boric acid)' (kilogram, RoW, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# 	 👉 (25974, 25987) to A1_dripresistantmaterial
# 6. Exchange: 0.027 kilogram 'medium filler' (kilogram, NL, None) to 'A1, pavement, materials, A (excl. own material)' (kilogram, NL, None)>
# 	 👉 (25977, 25987) to A1_mediumfiller
# 7. Exchange: 0.0094 kilogram 'crushed stone, from quarry in Europe, excluding transport to the Netherlands' (kilogram, NL, None) to 'A1, pavement, materials, A (own material)' (kilogram, NL, None)>
# 	 👉 (25976, 25988) to A1_ownmaterial
# 8. Exchange: 0.0103 ton kilometer 'market for transport, freight, lorry, unspecified' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (bitumen)' (kilogram, NL, None)>
# 	 👉 (18370, 25990) to A2_bitumen
# 9. Exchange: 0.5468313000000001 ton kilometer 'market for transport, freight, sea, ferry' (ton kilometer, GLO, None) to 'A2, pavement, transport to plant, A (crushed stone)' (kilogram, NL, None)>
# 	 👉 (10822, 25991) to A2_crushedstone3_sv
# 10. Exchange: 0.031063300000000005 ton kilometer 'market for transport, freight, inland waterways, barge' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (crushed stone)' (kilogram, NL, None)>
# 	 👉 (9408, 25991) to A2_crushedstone3_iv
# 11. Exchange: 0.014652500000000002 ton kilometer 'market for transport, freight, lorry, unspecified' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (crushed stone)' (kilogram, NL, None)>
# 	 👉 (18370, 25991) to A2_crushedstone3_t
# 12. Exchange: 0.0004982 ton kilometer 'market for transport, freight, inland waterways, barge' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (own material)' (kilogram, NL, None)>
# 	 👉 (9408, 25992) to A2_ownmaterial_iv
# 13. Exchange: 0.000235 ton kilometer 'market for transport, freight, lorry, unspecified' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (own material)' (kilogram, NL, None)>
# 	 👉 (18370, 25992) to A2_ownmaterial_t
# 14. Exchange: 0.022572000000000002 ton kilometer 'market for transport, freight, inland waterways, barge' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (crushed sand)' (kilogram, NL, None)>
# 	 👉 (9408, 25993) to A2_crushedsand_iv
# 15. Exchange: 0.0008550000000000001 ton kilometer 'market for transport, freight, lorry, unspecified' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (crushed sand)' (kilogram, NL, None)>
# 	 👉 (18370, 25993) to A2_crushedsand_t
# 16. Exchange: 0.00037170000000000004 ton kilometer 'market for transport, freight, lorry, unspecified' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (drip resistant material)' (kilogram, NL, None)>
# 	 👉 (18370, 25994) to A2_dripresistantmaterial
# 17. Exchange: 0.003672 ton kilometer 'market for transport, freight, lorry, unspecified' (ton kilometer, RER, None) to 'A2, pavement, transport to plant, A (filler)' (kilogram, NL, None)>
# 	 👉 (18370, 25995) to A2_mediumfiller
# 18. Exchange: 0.00561 kilowatt hour 'market for electricity, low voltage' (kilowatt hour, NL, None) to 'A3, pavement, production, A' (kilogram, NL, None)>
# 	 👉 (25065, 25996) to A3_electricity
# 19. Exchange: 0.2532 megajoule 'heat production, natural gas, at industrial furnace >100kW' (megajoule, Europe without Switzerland, None) to 'A3, pavement, production, A' (kilogram, NL, None)>
# 	 👉 (20515, 25996) to A3_naturalgas
# 20. Exchange: 0.0042959999999999995 megajoule 'diesel, burned in building machine' (megajoule, GLO, None) to 'A3, pavement, production, A' (kilogram, NL, None)>
# 	 👉 (18987, 25996) to A3_diesel
# 21. Exchange: 0.033299999999999996 ton kilometer 'transport, freight, lorry >32 metric ton, EURO5' (ton kilometer, RER, None) to 'A4, pavement, transport to site' (kilogram, NL, None)>
# 	 👉 (16115, 25997) to A4_distance_EURO5
# 22. Exchange: 0.0111 ton kilometer 'transport, freight, lorry >32 metric ton, EURO6' (ton kilometer, RER, None) to 'A4, pavement, transport to site' (kilogram, NL, None)>
# 	 👉 (8986, 25997) to A4_distance_EURO6
# 23. Exchange: 0.011460000000000001 megajoule 'A5, diesel, burned in building machine' (megajoule, GLO, None) to 'A5, pavement, construction' (kilogram, NL, None)>
# 	 👉 (25948, 25998) to A5_construction
# 24. Exchange: 0.027562 megajoule 'C1, diesel, burned in building machine' (megajoule, GLO, None) to 'C1, pavement, demolition' (kilogram, NL, None)>
# 	 👉 (25949, 26002) to C1_removal
# 25. Exchange: 0.033299999999999996 ton kilometer 'transport, freight, lorry >32 metric ton, EURO5' (ton kilometer, RER, None) to 'C2, pavement, transport to processing' (kilogram, NL, None)>
# 	 👉 (16115, 26003) to C2_distance_EURO5
# 26. Exchange: 0.0111 ton kilometer 'transport, freight, lorry >32 metric ton, EURO6' (ton kilometer, RER, None) to 'C2, pavement, transport to processing' (kilogram, NL, None)>
# 	 👉 (8986, 26003) to C2_distance_EURO6
# 27. Exchange: 0.006623 megajoule 'diesel, burned in building machine' (megajoule, GLO, None) to 'C3, pavement, processing (crane and shovel)' (kilogram, NL, None)>
# 	 👉 (18987, 26005) to C3_craneandshovel
# 28. Exchange: 0.006623 megajoule 'diesel, burned in building machine' (megajoule, GLO, None) to 'C3, pavement, processing (breaking)' (kilogram, NL, None)>
# 	 👉 (18987, 26006) to C3_breaker

# %% [markdown]
# Here is a dictionnary with the coords + vector with the samples.

# %%
counter = 0
for k, v in coords_samples_map.items():
    counter +=1
    print(f"{counter}. {k} --array-> {v}")
# Out:
# 1. (25975, 25987) --array-> [0.29996745 0.32703866 0.30015698 ... 0.3049856  0.30737276 0.29226108]
# 2. (8553, 25987) --array-> [0.0425576  0.03969113 0.04069381 ... 0.04056687 0.03873746 0.04120409]
# 3. (25976, 25987) --array-> [0.59119169 0.57735947 0.57916985 ... 0.58078443 0.56440685 0.59239116]
# 4. (17503, 25987) --array-> [0.03511603 0.03214571 0.03528521 ... 0.03615064 0.03500219 0.03637127]
# 5. (25974, 25987) --array-> [0.00200194 0.00200153 0.00201293 ... 0.00218769 0.00213234 0.00218444]
# 6. (25977, 25987) --array-> [0.02564781 0.02890423 0.02731286 ... 0.02727033 0.02606585 0.02617468]
# 7. (25976, 25988) --array-> [0.00973153 0.00924391 0.00957255 ... 0.00958156 0.00904519 0.00980764]
# 8. (18370, 25990) --array-> [0.0098724  0.01123424 0.01289974 ... 0.00780484 0.00659053 0.00662358]
# 9. (10822, 25991) --array-> [0.74794219 0.38524552 0.31259779 ... 0.78730368 1.03991455 0.66707487]
# 10. (9408, 25991) --array-> [0.0294236  0.02355408 0.02403601 ... 0.02609757 0.03371037 0.02409302]
# 11. (18370, 25991) --array-> [0.01619152 0.02389217 0.01205278 ... 0.02271711 0.01840923 0.01164081]
# 12. (9408, 25992) --array-> [0.00145551 0.00205923 0.0007436  ... 0.00156688 0.00141021 0.00194624]
# 13. (18370, 25992) --array-> [0.00021111 0.00023571 0.00019175 ... 0.00029571 0.00022969 0.00020743]
# 14. (9408, 25993) --array-> [0.02803277 0.0140029  0.04603916 ... 0.03353731 0.01958915 0.01239642]
# 15. (18370, 25993) --array-> [0.00090166 0.00090004 0.00111914 ... 0.00067393 0.0012919  0.00042058]
# 16. (18370, 25994) --array-> [0.00035124 0.00031885 0.00040493 ... 0.00053785 0.00042634 0.00036396]
# 17. (18370, 25995) --array-> [0.00449594 0.00272188 0.00337131 ... 0.00494718 0.00417135 0.00497812]
# 18. (25065, 25996) --array-> [0.00563938 0.00612362 0.0055311  ... 0.00570915 0.00566691 0.00565816]
# 19. (20515, 25996) --array-> [0.30140834 0.28295018 0.27534998 ... 0.28365752 0.27913168 0.28388683]
# 20. (18987, 25996) --array-> [0.00382432 0.00373897 0.00392981 ... 0.00375521 0.00374667 0.00349413]
# 21. (16115, 25997) --array-> [0.02385366 0.03690109 0.02351683 ... 0.02689969 0.04272767 0.0367072 ]
# 22. (8986, 25997) --array-> [0.00795122 0.01230036 0.00783894 ... 0.00896656 0.01424256 0.01223573]
# 23. (25948, 25998) --array-> [0.00971557 0.01039928 0.01000409 ... 0.0103274  0.01010723 0.0096138 ]
# 24. (25949, 26002) --array-> [0.02431744 0.02503901 0.02394965 ... 0.02404345 0.02430759 0.02375863]
# 25. (16115, 26003) --array-> [0.03562421 0.02275548 0.02374094 ... 0.03466593 0.05807913 0.01392804]
# 26. (8986, 26003) --array-> [0.01187474 0.00758516 0.00791365 ... 0.01155531 0.01935971 0.00464268]
# 27. (18987, 26005) --array-> [0.00600252 0.00600731 0.00588028 ... 0.0056302  0.00624567 0.00604022]
# 28. (18987, 26006) --array-> [0.00545812 0.00620634 0.00601627 ... 0.00585346 0.00552031 0.00553195]

# %%
# cml_methods = [m for m in bd.methods if m[0] == "CML v4.8 2016"]
cml_method_gwp = (
    "CML v4.8 2016",
    "climate change",
    "global warming potential (GWP100)",
)

# %% [markdown]
# ## Regular LCA from activity + method

# %%
a_lca = bc.LCA({pavement_complete_a: 1}, cml_method_gwp)

# %%
a_lca.lci()
a_lca.lcia()
a_lca.score
# Out:
# 0.15512695599913062

# %% [markdown]
# ## LCA using datapackages

# %%
bd.prepare_lca_inputs??
# Out:
# Signature:
# bd.prepare_lca_inputs(
#     demand=None,
#     method=None,
#     weighting=None,
#     normalization=None,
#     demands=None,
#     remapping=True,
#     demand_database_last=True,
# )
# Source:
# def prepare_lca_inputs(
#     demand=None,
#     method=None,
#     weighting=None,
#     normalization=None,
#     demands=None,
#     remapping=True,
#     demand_database_last=True,
# ):
#     """Prepare LCA input arguments in Brightway 2.5 style."""
#     if not projects.dataset.data.get("25"):
#         raise Brightway2Project(
#             "Please use `projects.migrate_project_25` before calculating using Brightway 2.5"
#         )
#
#     databases.clean()
#     data_objs = []
#     remapping_dicts = None
#
#     if demands:
#         demand_database_names = [
#             db_label for dct in demands for db_label, _ in unpack(dct)
#         ]
#     elif demand:
#         demand_database_names = [db_label for db_label, _ in unpack(demand)]
#     else:
#         demand_database_names = []
#
#     if demand_database_names:
#         database_names = set.union(
#             *[
#                 Database(db_label).find_graph_dependents()
#                 for db_label in demand_database_names
#             ]
#         )
#
#         if demand_database_last:
#             database_names = [
#                 x for x in database_names if x not in demand_database_names
#             ] + demand_database_names
#
#         data_objs.extend([Database(obj).datapackage() for obj in database_names])
#
#         if remapping:
#             # This is technically wrong - we could have more complicated queries
#             # to determine what is truly a product, activity, etc.
#             # However, for the default database schema, we know that each node
#             # has a unique ID, so this won't produce incorrect responses,
#             # just too many values. As the dictionary only exists once, this is
#             # not really a problem.
#             reversed_mapping = {
#                 i: (d, c)
#                 for d, c, i in AD.select(AD.database, AD.code, AD.id)
#                 .where(AD.database << database_names)
#                 .tuples()
#             }
#             remapping_dicts = {
#                 "activity": reversed_mapping,
#                 "product": reversed_mapping,
#                 "biosphere": reversed_mapping,
#             }
#
#     if method:
#         assert method in methods
#         data_objs.append(Method(method).datapackage())
#     if weighting:
#         assert weighting in weightings
#         data_objs.append(Weighting(weighting).datapackage())
#     if normalization:
#         assert normalization in normalizations
#         data_objs.append(Normalization(normalization).datapackage())
#
#     if demands:
#         indexed_demand = [{get_id(k): v for k, v in dct.items()} for dct in demands]
#     elif demand:
#         indexed_demand = {get_id(k): v for k, v in demand.items()}
#     else:
#         indexed_demand = None
#
#     return indexed_demand, data_objs, remapping_dicts
# File:      ~/anaconda3/envs/ua_pmlca/lib/python3.11/site-packages/bw2data/compat.py
# Type:      function

# %%
# the following function returns:
# indexed_demand, data_objs, remapping_dicts
# that follow the data package spec
indexed_demand, data_objs, remapping_dicts = bd.prepare_lca_inputs(
    {pavement_complete_a: 1}, cml_method_gwp
)

# %%
indexed_demand
# Out:
# {26010: 1}

# %%
data_objs
# Out:
# [<bw_processing.datapackage.Datapackage at 0x1083a8a50>,
#  <bw_processing.datapackage.Datapackage at 0x2a1cbac50>,
#  <bw_processing.datapackage.Datapackage at 0x2a1504950>,
#  <bw_processing.datapackage.Datapackage at 0x2a1e35cd0>]

# %%
remapping_dicts
# Out:
# {'activity': {25986: ('asphalt', 'A1_materials_A'),
#   25987: ('asphalt', 'A1_materials_A_excl.ownmaterial'),
#   25988: ('asphalt', 'A1_materials_A_ownmaterial'),
#   25978: ('asphalt', 'A1_materials_B'),
#   25989: ('asphalt', 'A2_transport_to_plant_A'),
#   25990: ('asphalt', 'A2_transport_to_plant_A_bitumen'),
#   25993: ('asphalt', 'A2_transport_to_plant_A_crushedsand'),
#   25991: ('asphalt', 'A2_transport_to_plant_A_crushedstone'),
#   25994: ('asphalt', 'A2_transport_to_plant_A_dripresistantmaterial'),
#   25995: ('asphalt', 'A2_transport_to_plant_A_filler'),
#   25992: ('asphalt', 'A2_transport_to_plant_A_ownmaterial'),
#   25979: ('asphalt', 'A2_transport_to_plant_B'),
#   25980: ('asphalt', 'A2_transport_to_plant_B_bitumen'),
#   25982: ('asphalt', 'A2_transport_to_plant_B_crushedsand'),
#   25981: ('asphalt', 'A2_transport_to_plant_B_crushedstone'),
#   25983: ('asphalt', 'A2_transport_to_plant_B_dripresistantmaterial'),
#   25984: ('asphalt', 'A2_transport_to_plant_B_filler'),
#   25996: ('asphalt', 'A3_production_A'),
#   25985: ('asphalt', 'A3_production_B'),
#   25997: ('asphalt', 'A4_transport_to_site'),
#   25998: ('asphalt', 'A5_construction'),
#   25999: ('asphalt', 'B_use'),
#   26001: ('asphalt', 'B_use_HDVplus'),
#   26000: ('asphalt', 'B_use_carandHDV'),
#   26002: ('asphalt', 'C1_demolition'),
#   26003: ('asphalt', 'C2_transport'),
#   26004: ('asphalt', 'C3_processing'),
#   26006: ('asphalt', 'C3_processing_breaking'),
#   26005: ('asphalt', 'C3_processing_craneandshovel'),
#   26010: ('asphalt', 'DZOAB, A'),
#   26008: ('asphalt', 'DZOAB, A, PVI'),
#   26009: ('asphalt', 'DZOAB, B'),
#   26007: ('asphalt', 'DZOAB, B, PVI'),
#   25975: ('asphalt', 'asphalt_granulate'),
#   25976: ('asphalt', 'crushed_stone'),
#   25977: ('asphalt', 'medium_filler'),
#   3775: ('biosphere3', '00012c0a-9bff-4787-a7eb-56c3d2f43692'),
#   4077: ('biosphere3', '00143719-33a7-5738-aa1b-131f97b4fef3'),
#   2765: ('biosphere3', '0015315d-a2b8-4b72-8e60-0d34a72e6de8'),
#   286: ('biosphere3', '0015ec22-72cb-4af1-8c7b-0ba0d041553c'),
#   3084: ('biosphere3', '0017271e-7df5-40bc-833a-36110c1fe5d5'),
#   2124: ('biosphere3', '001790f3-fd86-4a0d-a2a1-06c7099d90c8'),
#   3688: ('biosphere3', '0017ce28-9f7a-404b-ad55-d3f43ad13cae'),
#   4475: ('biosphere3', '004dbd05-6759-507a-a7f6-9f288706a1cd'),
#   1401: ('biosphere3', '0061b12a-9084-499b-9fc0-bf66025198eb'),
#   1988: ('biosphere3', '006aa3f7-59ba-450f-aa45-a2b2d1752647'),
#   2423: ('biosphere3', '007de693-1d9e-40a5-a8b4-3d11bce8be9a'),
#   817: ('biosphere3', '00907a61-b501-4f47-b688-1dc2b51d48c1'),
#   4680: ('biosphere3', '0097bf60-3729-40b6-94d0-06bd6146cfc2'),
#   2622: ('biosphere3', '0098b967-2131-43d2-b684-254583fbadc7'),
#   2229: ('biosphere3', '009a49e8-09a7-4432-9cb9-f2dd18e8f922'),
#   202: ('biosphere3', '009f3374-e604-4e24-88f5-d785cd93aac7'),
#   423: ('biosphere3', '00acb9f0-1640-4f8c-89ef-d857e1428be0'),
#   2806: ('biosphere3', '00d2fef1-e4d4-4a16-8e81-b8cc514e4c25'),
#   1273: ('biosphere3', '00df61ec-de0a-4f06-8736-839c6d225859'),
#   1584: ('biosphere3', '00e73fdb-98df-4a03-8290-79931cddfd12'),
#   2409: ('biosphere3', '01056d4b-f9b0-4dfc-b8d9-8407c8376efb'),
#   2821: ('biosphere3', '01174955-d4f9-4825-9188-791b79abc8e1'),
#   1945: ('biosphere3', '01248058-8a0f-40f6-8555-13ec37c7931d'),
#   4041: ('biosphere3', '0124b342-4bdd-5cbf-ba2a-dce8a259755c'),
#   2194: ('biosphere3', '01285299-c683-4e15-b654-201987a7a738'),
#   138: ('biosphere3', '0131a35d-1d37-46ee-aed2-5ca12ac07ad4'),
#   352: ('biosphere3', '013a65bf-5b9e-4621-bd60-14909fd4cbc6'),
#   4481: ('biosphere3', '01497ecf-a26d-5f6b-b2fd-98f53a30e1c1'),
#   2769: ('biosphere3', '014bd81b-88c7-4a81-b872-201dcbfb8bbf'),
#   211: ('biosphere3', '016da38a-40a6-483c-b328-9782dc46e802'),
#   4327: ('biosphere3', '017ada59-ad5d-5eef-9897-392720039d55'),
#   2562: ('biosphere3', '017be306-b88a-4d3a-a906-b8734b72b6fb'),
#   1320: ('biosphere3', '019ad37a-2728-455e-aa8d-c921d26c3cc7'),
#   4017: ('biosphere3', '01b9f1e8-4423-5393-ba63-2067935bdb13'),
#   3833: ('biosphere3', '01c12fca-ad8b-4902-8b48-2d5afe3d3a0f'),
#   3489: ('biosphere3', '01d052a5-9c4b-4c3a-8593-2e651c0a5bdf'),
#   3036: ('biosphere3', '01e16652-6f42-42f4-a23d-d10f166aaec9'),
#   4454: ('biosphere3', '01e5e64c-19ef-59c7-b350-7c46e691205a'),
#   2444: ('biosphere3', '01f511e2-7030-45f0-abb7-c24a4fae698b'),
#   3169: ('biosphere3', '020182dd-907f-4a99-b1f7-f28aae3d11ef'),
#   4282: ('biosphere3', '02156abf-3839-5778-897a-4c06444701d4'),
#   2954: ('biosphere3', '0217e70b-e467-4ec6-8800-09d011b7e689'),
#   1970: ('biosphere3', '021b8f30-26ac-4012-880a-69bfd65bfed4'),
#   2853: ('biosphere3', '02381700-f27e-4ffa-b58f-e7309ad7f9e7'),
#   3320: ('biosphere3', '024b1a73-0cff-4b49-9e1e-7d75110f1e31'),
#   159: ('biosphere3', '024c9722-1e88-412b-8c4b-10c532be8dca'),
#   2585: ('biosphere3', '024e919d-91ee-47c7-9f0b-ebe851cc61fb'),
#   1454: ('biosphere3', '025fcb20-0591-4bae-80fc-7c34e9af2e7b'),
#   1887: ('biosphere3', '0267272f-ea07-498a-9723-43583f115b46'),
#   1024: ('biosphere3', '02703daf-fde4-489a-b7e5-523e46151312'),
#   4446: ('biosphere3', '02801b46-cb56-5c8e-bdd3-00a24468d343'),
#   3815: ('biosphere3', '029af65d-7b19-4189-9c92-81fc03909665'),
#   1121: ('biosphere3', '02a7b111-6538-4496-a7cc-e03ea5b649bf'),
#   4590: ('biosphere3', '02d61089-c043-569a-a97d-981c5bbe7e7e'),
#   200: ('biosphere3', '02dd7309-b7c2-47bb-82c8-09345be9c2bb'),
#   3755: ('biosphere3', '02e8658e-3c88-404c-865d-4d4934661ea6'),
#   3546: ('biosphere3', '02eb30a8-ed7c-456b-a1fe-2cdffea4fb8d'),
#   1141: ('biosphere3', '0315d855-dff2-44af-bb37-1b855df53d69'),
#   2569: ('biosphere3', '031a15fd-8cd2-49f5-ada6-526313c6e457'),
#   4521: ('biosphere3', '032b609f-bee9-54e9-88b1-4502d98b22ef'),
#   247: ('biosphere3', '033d3a16-e1a2-4ce8-8769-f4ea867801ca'),
#   1240: ('biosphere3', '033fb239-a6c7-4486-9f92-f5a80b346778'),
#   4467: ('biosphere3', '035bc67b-1bd2-5014-ad8c-470d2a3b9675'),
#   2551: ('biosphere3', '03606bd1-8f71-4667-9b93-4f5e3b28249e'),
#   88: ('biosphere3', '0367c22a-f1f5-48bc-8dea-95e784d19df2'),
#   1352: ('biosphere3', '03758df7-503a-400e-bc7b-ec05825761a5'),
#   4564: ('biosphere3', '0390d424-73c6-579e-8c8d-4a544f1698f4'),
#   2671: ('biosphere3', '03964ba4-c637-480e-af78-6bb46e9dac37'),
#   2906: ('biosphere3', '03a1f7e6-f18b-4d49-b40b-5f52d1d9fb5c'),
#   1224: ('biosphere3', '03b279a7-4626-4703-a451-d0650599dbd9'),
#   3994: ('biosphere3', '03b40051-311b-5e37-aad1-ea811907cc90'),
#   3366: ('biosphere3', '03bd55c6-c37d-4205-aaa2-3c1f3759a0cd'),
#   3498: ('biosphere3', '03c9b5ac-a8f1-4a10-a0a5-b01f699545d1'),
#   4598: ('biosphere3', '03ccc7a5-9dfd-5fee-bb4a-24ca9b22d640'),
#   1513: ('biosphere3', '03e91172-fca0-47f3-9014-22ae3136251b'),
#   4304: ('biosphere3', '03f3255b-efb7-5a1e-8288-0a5e7bfbe791'),
#   4067: ('biosphere3', '0407ec6b-8635-57d0-b250-b06e53b28d32'),
#   1725: ('biosphere3', '040b40e8-bc9f-4219-ba9f-b648cb4c7a98'),
#   765: ('biosphere3', '04279d50-d748-4d84-b004-8c90ccb044e2'),
#   56: ('biosphere3', '042de84f-261d-4e29-bb7d-f43601cc2c7d'),
#   3676: ('biosphere3', '042e5892-cd59-4e95-949e-cacce0e6a590'),
#   1589: ('biosphere3', '0437e787-ef47-4a50-b11f-df7c743e860c'),
#   2422: ('biosphere3', '044b9b1d-0406-4da9-bc8a-f180176e7ed9'),
#   3479: ('biosphere3', '045f7de9-60d5-4916-a504-5a1002a6e97e'),
#   2041: ('biosphere3', '046887e9-5de9-44c0-8461-3c6da8e9e4b1'),
#   4512: ('biosphere3', '047dd1b5-69c2-542a-bd2d-8fb88d196e24'),
#   1704: ('biosphere3', '0485e80e-e793-4ec8-b50b-5ac6c2e6206f'),
#   2840: ('biosphere3', '0486ee88-c74a-479e-aa6f-2fbc4a96378d'),
#   955: ('biosphere3', '048baf1e-6cdc-44a5-92e2-32d15ff54885'),
#   2878: ('biosphere3', '049a1473-3a62-4121-982b-5d15d0f2c683'),
#   1644: ('biosphere3', '04a6edb8-624a-484e-8f85-d771657adae7'),
#   2876: ('biosphere3', '04abe114-7939-4935-9281-49e5d89cc1bc'),
#   4493: ('biosphere3', '04b5664e-7ad4-5b04-a859-ba1ae903d310'),
#   634: ('biosphere3', '04cd03b8-8206-4d3a-a910-59ffc0550c2c'),
#   876: ('biosphere3', '04eb0695-e67b-46e5-9516-da6bde119822'),
#   1107: ('biosphere3', '04f42988-6207-4d09-a91f-155be8d27eb0'),
#   374: ('biosphere3', '04f9be83-433e-4564-af72-98e463e5b616'),
#   1360: ('biosphere3', '050da0cd-2957-45a9-ae7a-ace372083fe5'),
#   3764: ('biosphere3', '05136060-b6a6-4383-ae42-6ca90aeec59a'),
#   4703: ('biosphere3', '051aaf7a-6c1a-4e86-999f-85d5f0830df6'),
#   2634: ('biosphere3', '0539c713-83e6-49d1-8738-1ba43e8bc2f8'),
#   1734: ('biosphere3', '0545c382-2312-43b6-9ec3-63dbb1438565'),
#   993: ('biosphere3', '0555dc8e-d8b3-4da1-afaa-a2144758d590'),
#   370: ('biosphere3', '05573d40-39f4-4b4e-98be-2afa50a3b533'),
#   452: ('biosphere3', '055bf521-b162-4172-b7db-da4df197d671'),
#   2593: ('biosphere3', '0561e8f7-bb2b-45b7-b4ab-e750f6842981'),
#   2715: ('biosphere3', '05909c8c-153e-4969-aaa8-e735054b8ee2'),
#   3031: ('biosphere3', '059d4f43-8764-4b5e-95eb-c94df9913a55'),
#   967: ('biosphere3', '059e6a26-7035-4621-a360-c71c5778eec8'),
#   361: ('biosphere3', '05bd7a83-0c53-4e95-b1eb-1140742f4176'),
#   183: ('biosphere3', '05bfed24-3408-42a2-9208-daec1538905d'),
#   3182: ('biosphere3', '05d248c7-0159-49c6-88f8-bd4aa70f4894'),
#   4610: ('biosphere3', '05f078ed-c834-45e3-aea0-05609ca93b4c'),
#   3659: ('biosphere3', '0605e241-ce98-4c10-8c61-d0a1775cdcb0'),
#   549: ('biosphere3', '061259d7-7bcc-4298-af3a-63d084191988'),
#   2379: ('biosphere3', '061c7a46-3728-48fa-8240-7a8841e6ca6f'),
#   2501: ('biosphere3', '061d04a0-af1d-4884-bdd3-997b6cd5550f'),
#   1981: ('biosphere3', '0628ac74-2a0d-4a13-aaef-14486431dc35'),
#   545: ('biosphere3', '062a6faf-b1a5-4a6a-aa02-47ae3ec566a8'),
#   225: ('biosphere3', '063a0cee-aa71-4ea6-85ca-045c74ca1a66'),
#   3073: ('biosphere3', '06449f0f-08af-4ca6-8c23-afd06c887810'),
#   2583: ('biosphere3', '064ac501-cea3-42fc-918c-6b17c113a764'),
#   2788: ('biosphere3', '0650f48f-c6c9-44ae-ac49-c3bae05220c3'),
#   3532: ('biosphere3', '06699be8-f522-427e-89b5-8ad948a39ecb'),
#   639: ('biosphere3', '066a904d-beba-47a4-a153-3981ca3554e0'),
#   462: ('biosphere3', '06874cbb-2daf-4981-a55e-2c38be5b7277'),
#   2014: ('biosphere3', '06a2e2b7-0c98-4a77-8cc9-84349e2f3fcf'),
#   4650: ('biosphere3', '06a42317-47bd-481d-b5ce-e091843497c6'),
#   1614: ('biosphere3', '06a4fedf-dab4-4ef1-90df-1d0ce8fe6477'),
#   140: ('biosphere3', '06b8a67f-5044-4060-be71-04e1dfc31e24'),
#   2400: ('biosphere3', '06c8168d-a28d-4e23-9505-a0fb462f9367'),
#   3608: ('biosphere3', '06d4812b-6937-4d64-8517-b69aabce3648'),
#   2989: ('biosphere3', '06ee87f5-4946-4ecd-9615-b4723595fbaf'),
#   1035: ('biosphere3', '06f0a67c-ec68-435d-8c32-0decd79a4a1a'),
#   2322: ('biosphere3', '070dc6b3-0976-45a0-803e-0a87d7e96959'),
#   3303: ('biosphere3', '070f9c6e-584d-40ed-8b07-6b1f7f75dd3f'),
#   3687: ('biosphere3', '071efe89-12e0-4ff8-80d1-4e6cf1e37233'),
#   4309: ('biosphere3', '07279b73-709f-4ac2-a9e1-82fbd01ce301'),
#   2406: ('biosphere3', '073e0dba-bc0b-4c76-89e2-2988f2b49459'),
#   4595: ('biosphere3', '0747406d-1fdc-5283-9a09-3101921c1d66'),
#   3607: ('biosphere3', '075e433b-4be4-448e-9510-9a5029c1ce94'),
#   1298: ('biosphere3', '07798b07-13be-41f9-b754-5b389695cf78'),
#   2439: ('biosphere3', '077b92b0-0610-48ba-9ff8-55c13e98364b'),
#   4350: ('biosphere3', '077d87be-0ee0-5caa-94e3-bd7b8c00772f'),
#   825: ('biosphere3', '0782d8ff-80e5-47a7-a2ba-3ba40ab60b60'),
#   4535: ('biosphere3', '07848a8e-1143-5eab-aa66-dddf41a639e7'),
#   1652: ('biosphere3', '0795345f-c7ae-410c-ad25-1845784c75f5'),
#   3936: ('biosphere3', '07a5e6ef-e95e-52ab-83ca-073b0727b0a0'),
#   1446: ('biosphere3', '07f704a2-2746-4364-bcfd-606cefc30715'),
#   4303: ('biosphere3', '08151735-9d1b-4b1c-a8b1-f341ade54f2f'),
#   3784: ('biosphere3', '081ea9c3-9cbe-41d7-a962-840833ba98db'),
#   3520: ('biosphere3', '0822b867-9dca-4d5a-93c3-319d39b592cd'),
#   1307: ('biosphere3', '082903e4-45d8-4078-94cb-736b15279277'),
#   1460: ('biosphere3', '082c37bb-a9f2-46e7-97de-5a023050ab7a'),
#   2462: ('biosphere3', '08439a5d-5036-4e9f-89df-08239a6dbc33'),
#   1770: ('biosphere3', '085bfe35-58e0-4a33-850c-4cb87ce32352'),
#   1017: ('biosphere3', '086f6b04-002c-49a0-9be8-2bad29a9c17a'),
#   4090: ('biosphere3', '0878c1c6-4c1d-4f90-a2de-a9383855d5c6'),
#   1574: ('biosphere3', '0898b1e9-b747-4589-86b3-ff20fd74ce64'),
#   1913: ('biosphere3', '08a570d6-99a9-477b-8099-77fc2a8afafa'),
#   3311: ('biosphere3', '08b681c9-b5fc-46c8-beb5-5ee8bf31cef9'),
#   584: ('biosphere3', '08b928d8-1812-4e0b-b057-4bcaaba24865'),
#   2914: ('biosphere3', '08c3135c-9ac5-472b-9a0e-04f2f85099bb'),
#   4461: ('biosphere3', '08c34081-cb18-5b76-b5f5-4177434e7bc0'),
#   1427: ('biosphere3', '08c96ec9-3284-4871-8d79-7a43a164e96a'),
#   4436: ('biosphere3', '08c9d29a-ba22-54a0-a500-b9a4709e35cf'),
#   4429: ('biosphere3', '08e2dc43-788c-5dc2-9d38-37b2d802f60d'),
#   617: ('biosphere3', '08e8878b-4069-4b49-8bca-0dd7c9b44b71'),
#   2047: ('biosphere3', '08ebf986-d40a-4538-8aa7-21da2f99edf7'),
#   418: ('biosphere3', '08f3db43-3185-4d9d-846a-404e27928eaf'),
#   216: ('biosphere3', '08fd6c23-2f15-440a-a366-ebcc2b6b4f3d'),
#   4633: ('biosphere3', '09073fb9-ffae-579d-acfd-aebecb8b05ca'),
#   3234: ('biosphere3', '090cc44a-7ca1-46fc-98bf-5bc6f5afb0a6'),
#   867: ('biosphere3', '090e9aa9-a9a9-4878-9634-3ad0ba7fbc91'),
#   1072: ('biosphere3', '091d8157-f865-4858-8ceb-0a49ac84614b'),
#   3240: ('biosphere3', '09257283-72d9-4d13-838b-ee7f28e6d146'),
#   4616: ('biosphere3', '092d418f-3b03-5b45-bf32-0ba4b77cb570'),
#   788: ('biosphere3', '0930b6b8-d9c6-4462-966f-ac7495b63bed'),
#   3870: ('biosphere3', '094310bb-49db-5b2d-ae1b-e7b4ffca1d03'),
#   354: ('biosphere3', '0964b6e9-08a5-4103-8ad6-610e8cd718c1'),
#   2485: ('biosphere3', '096bf756-c3fa-4470-9059-ac1b059081e0'),
#   1803: ('biosphere3', '097cecfb-bed2-43a0-81b7-c153d0bb14b9'),
#   3476: ('biosphere3', '0985a2b2-b411-4c95-a955-1aa5bb64bd08'),
#   3612: ('biosphere3', '09872080-d143-4fb1-a3a5-647b077107ff'),
#   3188: ('biosphere3', '099aeca3-9b1a-44be-9b67-7bb90dffe37c'),
#   1180: ('biosphere3', '099b36ab-4c03-4587-87f4-2f81e337afb8'),
#   579: ('biosphere3', '09a68c14-01f6-4dee-ba29-8b7f400b72b5'),
#   951: ('biosphere3', '09db39be-d9a6-4fc3-8d25-1f80b23e9131'),
#   1610: ('biosphere3', '09e231fa-b1c2-4d63-9c57-7ea0e2210858'),
#   2841: ('biosphere3', '09f25c1d-3f19-428a-9167-cbd2d8857490'),
#   2426: ('biosphere3', '09f735ea-0a87-4e19-a660-d044db3a7118'),
#   3590: ('biosphere3', '0a0a8657-0cc0-4132-a31b-cb4b0a0f3f3a'),
#   2498: ('biosphere3', '0a11b30c-b502-414a-8b73-31375233cc17'),
#   1846: ('biosphere3', '0a17349d-b0d6-4dae-b3e6-c363df32148c'),
#   383: ('biosphere3', '0a250f4c-2bca-437d-8775-45e18e427e4a'),
#   3296: ('biosphere3', '0a2b3be6-e2b5-4878-a472-7deab6efc47d'),
#   3891: ('biosphere3', '0a366c38-2c07-56e8-b03f-e97f0080daa1'),
#   1230: ('biosphere3', '0a4d49cc-8a90-4ca2-8417-468951ae232b'),
#   4370: ('biosphere3', '0a57049c-a0d8-5f51-9ee6-cf77704a2fee'),
#   2203: ('biosphere3', '0a5e8a67-f9ae-48b3-bfa7-e9d37c30a191'),
#   4545: ('biosphere3', '0a65f0b0-fe77-564d-9bba-c9a8df2aa268'),
#   3257: ('biosphere3', '0a6ae675-cdf2-475d-b4ef-486e78757d65'),
#   3312: ('biosphere3', '0a75cbfb-253f-4378-874b-8fb1c9cfef60'),
#   2997: ('biosphere3', '0a7b2a91-5d35-400b-9a9e-30e195abfe73'),
#   3230: ('biosphere3', '0a7de246-d762-4210-8656-56e1f26249b6'),
#   875: ('biosphere3', '0abf9db7-b5a2-4c18-8ec6-aca3a7fb5579'),
#   2410: ('biosphere3', '0ace7678-a181-48e8-8728-d912a8b56c57'),
#   3887: ('biosphere3', '0ae80e4e-2e46-5292-a0d7-7526bebc603b'),
#   1594: ('biosphere3', '0af26a55-d357-469f-abad-8ced785cb4fb'),
#   3959: ('biosphere3', '0af51816-fa0b-5c76-bc65-92071535f15d'),
#   2062: ('biosphere3', '0b0d8098-ecbf-4020-afd6-4bcf9db686ce'),
#   1497: ('biosphere3', '0b0ea9d1-9c54-4e23-bcfc-1b8fc2cf0358'),
#   3302: ('biosphere3', '0b111253-26b5-4a03-97fb-ed7799c21797'),
#   3973: ('biosphere3', '0b27924a-660d-5cbc-8b67-c2d30dd91d39'),
#   2919: ('biosphere3', '0b28fc38-9334-42a9-bac1-a04c2832e79d'),
#   3722: ('biosphere3', '0b29cbc1-607c-4919-a6a6-802a3840ff4b'),
#   3761: ('biosphere3', '0b2a8601-aa6e-42e9-8091-21cba87c0f0c'),
#   2963: ('biosphere3', '0b316831-20fd-4f73-bfcf-c19e3485fc1f'),
#   4549: ('biosphere3', '0b57a7b0-adbb-5a03-9bdc-0d464136b9be'),
#   3554: ('biosphere3', '0b5b83a4-ef85-4db6-a739-79f8e00d5dac'),
#   4220: ('biosphere3', '0b5c0609-3456-5935-93ae-5414b08eeaca'),
#   690: ('biosphere3', '0b9159dd-305d-4add-802f-f7b780ed0289'),
#   4296: ('biosphere3', '0b94989b-2551-4069-bb11-4f9f48988cad'),
#   577: ('biosphere3', '0b9698ec-8b52-4986-8f9f-ad30915aa00c'),
#   262: ('biosphere3', '0ba582f8-3360-441a-a93c-ea15e87f7b0c'),
#   1134: ('biosphere3', '0bb03c13-6035-4e0c-88a7-2c7d0bcd4125'),
#   3850: ('biosphere3', '0bb38d46-04e7-52f2-99de-5861a8220a49'),
#   1417: ('biosphere3', '0bb66845-6ccf-4648-b565-2e704989d7c0'),
#   2263: ('biosphere3', '0bbb2dfe-6dc8-4a22-9d23-db140afb7faf'),
#   2362: ('biosphere3', '0bc097f2-00ee-416f-a275-2c05d1e6d482'),
#   747: ('biosphere3', '0bd0f9e3-d311-4673-b431-d079399a7151'),
#   1511: ('biosphere3', '0bd4b5ea-feb6-47d4-a657-c5b33b26fded'),
#   1362: ('biosphere3', '0bf92802-8b5e-43f5-a261-95c06bd5c551'),
#   3091: ('biosphere3', '0c150bb4-fd1a-43f8-b6c9-5dfda8dadb6c'),
#   3278: ('biosphere3', '0c1f1396-1b8f-4958-858c-1fde3a746125'),
#   1540: ('biosphere3', '0c209634-80bb-4909-8442-3189b7cb01d7'),
#   4678: ('biosphere3', '0c5de0d2-eb1e-4afe-a8de-b600d899516f'),
#   299: ('biosphere3', '0c77f5af-0a0b-4205-acb6-0b031c22029f'),
#   1459: ('biosphere3', '0c906b13-a938-4e0d-9722-ae52ffa41ecd'),
#   1110: ('biosphere3', '0cc9c42e-7ebf-4f34-b90f-cc3f6b5aa9a6'),
#   1501: ('biosphere3', '0cdaaa7e-3c23-419d-8ad5-12dc93c2e1e3'),
#   2556: ('biosphere3', '0d213eaa-6dec-4669-b75e-4afeb06ac31d'),
#   4235: ('biosphere3', '0d218f74-181d-49b6-978c-8af836611102'),
#   1458: ('biosphere3', '0d30fcbb-9262-4026-8e0d-119fb12a04b0'),
#   1377: ('biosphere3', '0d3ccb17-b3fe-4c08-b7cb-458ed3ababf1'),
#   1682: ('biosphere3', '0d4989fd-00e3-4522-905f-2ab6a1bd5677'),
#   4632: ('biosphere3', '0d6c82cf-800b-586c-afed-b4e26ec14682'),
#   907: ('biosphere3', '0d6def86-f116-4da2-9f2f-c3d9dab2248d'),
#   1930: ('biosphere3', '0d7ef054-35e2-4d02-9113-574d7f022631'),
#   483: ('biosphere3', '0d7f8b87-12f4-4e83-a5a2-854e2f2b47de'),
#   272: ('biosphere3', '0d8a4e41-a58c-49f9-82dc-9d57b3d0602c'),
#   1975: ('biosphere3', '0d9f52b2-f2d5-46a3-90a3-e22ef252cc37'),
#   2867: ('biosphere3', '0db53406-fb79-497d-a9e7-fc2c8d425b81'),
#   1527: ('biosphere3', '0dc0bbb0-1141-4dff-b6a2-8bd5368e14af'),
#   4253: ('biosphere3', '0e0554ad-f6aa-472e-88e0-489f19bec2bb'),
#   2437: ('biosphere3', '0e066010-5511-4ce5-b7ff-446e58417a65'),
#   2458: ('biosphere3', '0e1c17ae-8144-4714-a7cd-786a5480f423'),
#   3789: ('biosphere3', '0e20b8fa-3f9a-41f2-b9aa-2b4e32c62264'),
#   3158: ('biosphere3', '0e2c8aa9-56be-4e7f-8f10-34f1baa70c0a'),
#   2072: ('biosphere3', '0e2e2f54-225f-4782-bfda-99bedacebee5'),
#   4243: ('biosphere3', '0e2f5e72-a754-5a14-bce5-6f8d66276d82'),
#   2071: ('biosphere3', '0e6489b3-cfcf-4563-9064-67637fc455de'),
#   3475: ('biosphere3', '0e6cf9f9-44ff-4395-ad3b-36109a32e6eb'),
#   261: ('biosphere3', '0e7c1a7b-cd98-4f8d-a619-a687d3e2cb48'),
#   2258: ('biosphere3', '0e7f417f-b5ec-4771-a47a-60cc451a8403'),
#   2384: ('biosphere3', '0e8f17d0-3e52-4f6f-bef9-60f6007a7aab'),
#   2074: ('biosphere3', '0e938bce-f780-4e2e-9de0-a8efd8c0804b'),
#   3330: ('biosphere3', '0e940fff-f3ba-41b4-a5c6-d53a88bfc707'),
#   1742: ('biosphere3', '0e9e6b81-0a68-4350-8368-566c083bd3e0'),
#   3146: ('biosphere3', '0eae6018-d930-452a-82a0-e4190dd09794'),
#   3803: ('biosphere3', '0eba8639-12c1-40ce-b1b6-e3394ec94dc0'),
#   1680: ('biosphere3', '0ebdb68a-f50d-4b0c-ad4b-3a1104d8b454'),
#   2898: ('biosphere3', '0ec59d21-92c1-492e-8e1e-f0f33f94f1b5'),
#   3535: ('biosphere3', '0ec92f76-932f-4407-bd4f-eb9aa426e099'),
#   363: ('biosphere3', '0eca2efa-6bc8-40c9-9721-84f53d3ca94b'),
#   1937: ('biosphere3', '0ed1b1a1-e56d-4860-bac7-d76a39bde930'),
#   1189: ('biosphere3', '0ee028c3-80c7-4377-97b1-81f1a732be2c'),
#   203: ('biosphere3', '0f02d06c-c44d-4681-a677-eff6aa3cd7e0'),
#   3314: ('biosphere3', '0f196b13-68bf-4deb-9fcd-ce7080618320'),
#   4092: ('biosphere3', '0f1b21d0-2780-4742-87f2-28fb21a44db5'),
#   226: ('biosphere3', '0f333e4d-e5ad-49e8-b24f-875456125ad4'),
#   3345: ('biosphere3', '0f3a98cd-b692-4801-86b5-b2222a953417'),
#   1044: ('biosphere3', '0f440cc0-0f74-446d-99d6-8ff0e97a2444'),
#   1655: ('biosphere3', '0f70e720-127e-44dc-bb85-438158235ab6'),
#   3879: ('biosphere3', '0f74b213-664e-5da8-b700-bf2c01a9c57a'),
#   2403: ('biosphere3', '0f8120d4-3365-4301-871c-b5d9716b008e'),
#   411: ('biosphere3', '0f901f59-84bd-42a5-9a4c-04bd8cac7fb9'),
#   1872: ('biosphere3', '0f907765-2a94-48a8-8978-55a2757d3e24'),
#   516: ('biosphere3', '0f923637-e322-44d8-9ff2-9c765d75e253'),
#   1657: ('biosphere3', '0f9f3e17-eb81-4adb-8170-049bc6b66728'),
#   4048: ('biosphere3', '0fa4f51e-b0dc-5d11-84d3-b32f0f3c88d5'),
#   1125: ('biosphere3', '0fbca534-f355-4477-b29f-7b5fc2fbce64'),
#   2656: ('biosphere3', '0fc1db69-f50d-4a88-b9d8-1446e691063c'),
#   3955: ('biosphere3', '0fe04bc3-350c-5755-8db2-919c16b85d6f'),
#   2958: ('biosphere3', '0ff15165-d761-48c9-9814-2d1dcdd56857'),
#   1639: ('biosphere3', '1013b9ec-a7b5-459c-be3d-74f61b9ce06e'),
#   4164: ('biosphere3', '10174d33-e2ca-5bd7-ae77-335c59edf286'),
#   2722: ('biosphere3', '101c756f-d7af-4c18-826f-2144b6a54f5f'),
#   768: ('biosphere3', '101f15ac-0698-49dd-b177-471a813ef78e'),
#   3443: ('biosphere3', '10319ea8-90db-4340-be33-b7182dca01db'),
#   2113: ('biosphere3', '103c41ab-69e6-4af9-9b4a-cbd3e2858c0d'),
#   4630: ('biosphere3', '10507b66-45a2-4f20-ae9c-609e8b4d07c8'),
#   1935: ('biosphere3', '10555050-586c-46b7-848e-9d90324d104b'),
#   475: ('biosphere3', '10571d92-ea97-4ac6-adb6-b25893a631cb'),
#   4363: ('biosphere3', '1064362b-4806-554e-8b6b-25fbe82b778d'),
#   1512: ('biosphere3', '106689fa-52d8-4f7d-aa5b-920122aaf1aa'),
#   1238: ('biosphere3', '1070d47d-3834-423e-9603-3626ecc162d8'),
#   676: ('biosphere3', '1088a788-1a99-4127-834e-d29c1fe47c74'),
#   3731: ('biosphere3', '108e9780-646b-448d-903b-609b3f65950b'),
#   2327: ('biosphere3', '109c3ee9-b9df-4c11-bd77-b8571773d9ad'),
#   2020: ('biosphere3', '10b69d7a-018d-44c6-9a5e-e67fc9475b86'),
#   1021: ('biosphere3', '10bb4bbd-818f-4dd1-a5bd-5105c43bc32f'),
#   2980: ('biosphere3', '10cbd2f7-c41b-4bb4-b636-d8fc15cf0282'),
#   3952: ('biosphere3', '10cf973e-9a4c-53a6-83e9-c2293909374d'),
#   1095: ('biosphere3', '10d26189-a688-4859-8aa9-525e058a07f0'),
#   3699: ('biosphere3', '10df31ce-d6ad-42b6-8fb2-9dfdb588e9ec'),
#   1713: ('biosphere3', '10e38581-58c8-4b27-85a4-6db6a83286ba'),
#   3906: ('biosphere3', '10e3b4c5-7c8f-58eb-9606-9a1a0a96598a'),
#   771: ('biosphere3', '10ebc72c-2c4b-45ea-abd8-cb7fe0805883'),
#   2824: ('biosphere3', '10ee01aa-ebd3-4232-bdbd-50a32218b70f'),
#   2666: ('biosphere3', '10ee0828-0340-4fe0-a3df-a9f3a8c6d939'),
#   1888: ('biosphere3', '10f2525f-b35b-4d8a-ad99-03acf1afce6b'),
#   4126: ('biosphere3', '110975e5-1bcd-51ab-9b87-246cfb417c55'),
#   4045: ('biosphere3', '110a04f0-af53-5499-b22e-79b1b91e5a66'),
#   188: ('biosphere3', '111c5f0c-3dda-4b7c-a5e2-aaada6ab6f79'),
#   4295: ('biosphere3', '113746e5-66a9-4d8c-b72b-4a99e7fcd052'),
#   330: ('biosphere3', '11a2a7b1-ab2f-47b8-9e29-6f33d5207fa6'),
#   2702: ('biosphere3', '11b6407e-a10b-477f-8dfd-53cb425f62b0'),
#   4487: ('biosphere3', '11eb55f5-7de5-59fa-90fe-a6821476dedb'),
#   43: ('biosphere3', '11f41c41-7733-49bc-b1b1-1f00fbade521'),
#   2200: ('biosphere3', '12051b95-831a-49c0-9a70-fbc0e8fb9af9'),
#   4032: ('biosphere3', '12264257-7f8b-4afe-b3cb-3ac28ca1661a'),
#   3940: ('biosphere3', '12352b0c-c809-5bc8-a9b8-6ad6f9900636'),
#   2843: ('biosphere3', '123b7b5a-cfc3-4dba-a14c-8481d3543f43'),
#   3851: ('biosphere3', '1247aa8b-3a24-552a-bddf-bb578e5d2dc5'),
#   1914: ('biosphere3', '12544a15-e0ef-48cb-a0e1-ee9cc0ec7592'),
#   1431: ('biosphere3', '1258b87f-6a94-4c0f-a51a-cef98a3bf534'),
#   4410: ('biosphere3', '125cffa2-ba58-5995-8645-24e7789cdccc'),
#   259: ('biosphere3', '127ff74d-018b-43b9-8a4e-fb5577d5ee5a'),
#   1016: ('biosphere3', '12840cef-c3b8-4ef2-b7d4-3a73dbd6a280'),
#   1530: ('biosphere3', '128e3b2b-08f7-4777-a984-0e3685e745ef'),
#   2424: ('biosphere3', '129c8923-0927-4aef-bdac-7373b2898606'),
#   2740: ('biosphere3', '12c12a5e-847f-4a94-be3b-21f14ff429fe'),
#   503: ('biosphere3', '12c7671c-e4aa-46c6-93c5-b6f9ac1c453b'),
#   2178: ('biosphere3', '12d6029e-3801-42ee-a1bc-1ebf936884fc'),
#   3816: ('biosphere3', '12e2fffe-08cd-451c-ad46-0b0a5db3c9ba'),
#   3176: ('biosphere3', '130bbacf-e7c7-4ffd-b109-4d576f1d02c1'),
#   2418: ('biosphere3', '130cedc6-f6ed-4f1b-bd1e-881177f79e74'),
#   1962: ('biosphere3', '131565d8-5d8d-466f-be1d-3615fb77da86'),
#   1942: ('biosphere3', '1329e7f0-ff40-45e2-8e46-a2192b87e407'),
#   2420: ('biosphere3', '13331e67-6006-48c4-bdb4-340c12010036'),
#   4294: ('biosphere3', '134c89a1-e244-4664-945c-5ebf5f394297'),
#   2894: ('biosphere3', '134ec0d7-3701-473c-a1a1-1982fd48ef4d'),
#   3308: ('biosphere3', '134ef10a-4423-4250-9331-08f654b0900d'),
#   1835: ('biosphere3', '13738d15-2256-40f6-99da-d802e5f4c747'),
#   1254: ('biosphere3', '137f2ebc-8f8b-41fc-9ff6-d32f42565d56'),
#   3648: ('biosphere3', '13825fb9-6e24-409a-bfcd-5dc4fd61ef98'),
#   3119: ('biosphere3', '13b07693-bf3c-4f08-8e21-a4a6b743106c'),
#   600: ('biosphere3', '13be989f-9a8e-420d-b27d-47c3565eb77c'),
#   1806: ('biosphere3', '13d2fabe-9282-4905-9dfc-5c859022835c'),
#   1772: ('biosphere3', '13d898ac-b9be-4723-a153-565e2a9144ac'),
#   1382: ('biosphere3', '13fb54aa-a54a-48de-b2ec-b9165dea111d'),
#   3858: ('biosphere3', '13fcf4c3-7800-5444-ba84-6d4b7e611ce6'),
#   2401: ('biosphere3', '14059c6a-2b32-4818-a9dc-93b8f21df2b3'),
#   3866: ('biosphere3', '140821a2-66bf-5600-9934-889cbf313c1e'),
#   677: ('biosphere3', '1417474c-bf73-4ffc-9eff-94a994bf76a8'),
#   2858: ('biosphere3', '141996d0-f260-4ef3-ad9a-809c54690595'),
#   1582: ('biosphere3', '141ec03e-9ec3-4cfe-853d-37cc66e1c333'),
#   1442: ('biosphere3', '142ce3b0-4bd6-47a3-9991-7c657c947ffe'),
#   3195: ('biosphere3', '1469e83d-2ac9-4e64-84e0-cfe37c85fd9d'),
#   1505: ('biosphere3', '1471acca-34ab-4e04-9bd6-e3825b20580f'),
#   2983: ('biosphere3', '147b91df-513b-4784-923a-180c2a5b1434'),
#   681: ('biosphere3', '14946240-b1ee-412c-b900-ed5728a4e684'),
#   3197: ('biosphere3', '14a8c75b-9985-4009-bf45-dc6d3bb4e52e'),
#   2064: ('biosphere3', '14b5c954-056b-4d06-8e2c-2848d85619b1'),
#   115: ('biosphere3', '14b6726a-44bf-4ad4-b933-02470d84c22a'),
#   2116: ('biosphere3', '14ca107c-315a-410b-af1b-35a886faebce'),
#   2654: ('biosphere3', '14cf8478-945a-47c6-91b2-f1f8293549b2'),
#   853: ('biosphere3', '14de323f-9e2d-4beb-b28e-6b93bae98da8'),
#   3218: ('biosphere3', '14e8ce09-acbd-4b33-abb8-e09416363971'),
#   2185: ('biosphere3', '14ea575b-5caa-4958-acf7-0bcc47f9cadf'),
#   1830: ('biosphere3', '14ee3991-b63b-47bc-989f-0f4db81f7c72'),
#   738: ('biosphere3', '15057e97-7b47-405e-8222-6ed5cf4e0087'),
#   1877: ('biosphere3', '1510adf1-ba02-42af-bca5-f1e0afc58092'),
#   1004: ('biosphere3', '1511586a-8f52-4e6b-bb46-78a0c083155f'),
#   1648: ('biosphere3', '151212b4-079b-43a2-96d5-a6eef59166ac'),
#   3934: ('biosphere3', '1516ec05-1677-553a-9ce7-748002246ecc'),
#   2847: ('biosphere3', '152e5a83-96e8-4f54-af42-4f0925a771ac'),
#   3905: ('biosphere3', '1541559e-1e25-5d7b-9d0b-dc45386e7c1c'),
#   1908: ('biosphere3', '1551f1cd-7cb7-4f68-a628-cb9301323c7b'),
#   150: ('biosphere3', '15545dca-018d-4f7f-aa1f-796b707180af'),
#   3236: ('biosphere3', '15648250-4537-4960-a6dc-0802d39c26a7'),
#   4506: ('biosphere3', '15742e1a-1434-5cce-8912-72bac6e7b60a'),
#   4546: ('biosphere3', '158011ab-894a-5bdd-9449-f25c57f1f5aa'),
#   4260: ('biosphere3', '1584734d-c5c8-42a5-aa51-0f6a92a9cc0d'),
#   4445: ('biosphere3', '158ce58f-9053-5b23-9db3-65fbb0b9106b'),
#   1484: ('biosphere3', '15a335be-9a71-431f-a0b0-56585fbafe5e'),
#   4428: ('biosphere3', '15ac8049-37ca-58dc-b4fa-2fde7781a527'),
#   2367: ('biosphere3', '15b58430-7bd4-4c6c-967e-514538c85b8d'),
#   309: ('biosphere3', '15bdfe3d-58b7-4cf3-a8db-0b16a8b9949b'),
#   4119: ('biosphere3', '15be40a9-968f-5247-9817-f4062dcf9bfd'),
#   1049: ('biosphere3', '15c4a3e0-bd82-4acd-a8fd-58aba60dd9fc'),
#   2706: ('biosphere3', '15c4b0d9-9004-4444-98f7-a0275a793673'),
#   490: ('biosphere3', '15ca802b-f541-44aa-bd33-35560a053193'),
#   3096: ('biosphere3', '15cfc784-a719-4230-ad2e-f4104d56c427'),
#   253: ('biosphere3', '15e54d5b-aba2-40a6-9aa8-aa2b8c432129'),
#   1172: ('biosphere3', '15f9ebbb-b1b5-4bf7-88c6-d99424f5eced'),
#   1160: ('biosphere3', '15fd8f0f-c3c2-4f63-b8d0-86793a22aacd'),
#   3113: ('biosphere3', '16167d62-361c-4ed9-bfeb-3ad4545e794c'),
#   2688: ('biosphere3', '16176f2c-6c9e-447b-99fb-e2f1d651c849'),
#   2164: ('biosphere3', '162b7095-c497-4b3c-a290-01ebe4bc9a08'),
#   2275: ('biosphere3', '16316600-f12a-410b-8726-3faee64de60a'),
#   3046: ('biosphere3', '163926e2-b4cc-42bb-ba7d-401028140985'),
#   1776: ('biosphere3', '16410099-57c2-4ad8-928a-d8ec91f1684f'),
#   1994: ('biosphere3', '16521d00-4b6f-464f-b5dd-8da4a27b15ca'),
#   1355: ('biosphere3', '1652c2e3-c6c5-49e1-9ad1-34c188087ca6'),
#   3175: ('biosphere3', '1653bf60-f682-4088-b02d-6dc44eae2786'),
#   1279: ('biosphere3', '165aaeac-93d1-4afd-adf2-e3d6c0eaf629'),
#   3990: ('biosphere3', '165e28f3-4377-573c-9d2f-52c664f43d42'),
#   1550: ('biosphere3', '168746ee-b79e-47d6-951e-b085e7e7130b'),
#   2293: ('biosphere3', '168c970b-91c9-4427-a3a0-6686ad6cc2c4'),
#   2084: ('biosphere3', '16916dd2-a145-4cb2-9769-19c551b2ff5e'),
#   4444: ('biosphere3', '16ab4f8f-e8d0-5b7c-9827-41e70d5fe6c5'),
#   591: ('biosphere3', '16addd86-288b-419a-8217-75e4197c5f9d'),
#   1301: ('biosphere3', '16bb633b-6a05-4f1a-8bab-9f4c121df099'),
#   3462: ('biosphere3', '16cd83f0-c5c0-4b6f-8dd0-26d4e3b9a017'),
#   1040: ('biosphere3', '16d7b9bd-003a-493b-8b98-b6986d3cae24'),
#   3339: ('biosphere3', '16d8a28a-bf21-46ff-ae18-6da39e53fa17'),
#   3706: ('biosphere3', '16ddda12-daf4-460c-83fb-c361bdbbc9e9'),
#   164: ('biosphere3', '16e15fb4-aee8-42b8-a303-70d61a9b723a'),
#   1170: ('biosphere3', '16eeda8a-1ea2-408e-ab37-2648495058dd'),
#   2286: ('biosphere3', '16f40b1c-f7c8-4100-9916-81a260493951'),
#   1324: ('biosphere3', '16fcd4f9-0bb8-4b84-8334-3ffb1a17aa74'),
#   2442: ('biosphere3', '16ff2790-3c88-4761-bb09-b91d981d2c30'),
#   469: ('biosphere3', '171528d9-6a7b-41cb-8c4c-60d2ad0955a1'),
#   458: ('biosphere3', '171aebab-b5e0-493f-8776-43e1a694666f'),
#   3135: ('biosphere3', '1727b41d-377e-43cd-bc01-9eaba946eccb'),
#   2465: ('biosphere3', '174d35ab-9974-4e6c-bbaf-180f4ccc36bf'),
#   1920: ('biosphere3', '17505bf8-40af-4580-8608-5841ff063d23'),
#   492: ('biosphere3', '1753af55-cfa1-4fb2-a059-33594a759982'),
#   496: ('biosphere3', '175baa64-d985-4c5e-84ef-67cc3a1cf952'),
#   4057: ('biosphere3', '176598c1-699c-5dd8-8c33-d269ff7f5edd'),
#   1855: ('biosphere3', '1784e16f-e070-4e2e-b567-182f8f6b9cbd'),
#   3760: ('biosphere3', '17955b10-4c04-4fff-91e7-cf89ef1a7cca'),
#   2355: ('biosphere3', '179c3a4c-4d0c-4928-b099-2652fac747cd'),
#   813: ('biosphere3', '17a5a406-333f-4b9e-8852-c2de50bc9585'),
#   2453: ('biosphere3', '17a7db69-d874-4ecd-af5d-48c98def445f'),
#   1470: ('biosphere3', '17a98e7f-a8fd-431d-9bb6-6c4bf3fc5517'),
#   1155: ('biosphere3', '17ae628d-e769-4aa3-a20e-9f9bad222bf2'),
#   3533: ('biosphere3', '17b87359-36f1-4ad3-a019-73e40fc2efc7'),
#   2797: ('biosphere3', '17bd5f8c-bd48-4cfc-80c0-1aa251f4bf43'),
#   1686: ('biosphere3', '17d135a5-2367-40d1-864b-fe817cd2284e'),
#   970: ('biosphere3', '17f06f74-feea-4b7c-a125-a67ae6e1dcfb'),
#   3848: ('biosphere3', '17f7e776-7934-54af-8c3c-ed0247cb697b'),
#   4348: ('biosphere3', '181b90a4-8213-551e-b44e-c94067da3993'),
#   341: ('biosphere3', '18282ab8-5b46-4c56-9038-588ed28a4a95'),
#   4052: ('biosphere3', '1836d8db-abda-5275-8445-4904f7a8f91d'),
#   3090: ('biosphere3', '183aa819-941d-48b4-9d47-7e725d1813bb'),
#   2157: ('biosphere3', '183f9856-03ab-464d-9366-8ef62077b510'),
#   2378: ('biosphere3', '18452b50-8c57-41d2-bbdd-37996c455771'),
#   3854: ('biosphere3', '185d4f1e-6d28-551b-8951-672805c4d8e5'),
#   534: ('biosphere3', '18636f13-f552-4136-a353-3b5a8e5f87d1'),
#   3456: ('biosphere3', '1869fd74-ed68-4814-9596-12315b1e810d'),
#   2533: ('biosphere3', '189372b3-0e83-4ee0-bf62-b65925068657'),
#   531: ('biosphere3', '1896b498-8d13-4f58-8c17-21fe57740158'),
#   2031: ('biosphere3', '18aa2daa-0188-4328-b24b-1ad1398ecf81'),
#   4544: ('biosphere3', '18aabc87-2728-5b28-bde2-595885b24b7f'),
#   1910: ('biosphere3', '18bcb736-db8a-445c-ba28-ca648838a1a0'),
#   2459: ('biosphere3', '18c5396a-1034-4226-a6f3-04c9963f8595'),
#   1624: ('biosphere3', '18c582fe-7336-4138-8797-2db8b7a754c7'),
#   430: ('biosphere3', '18ddd879-5496-4419-8ab7-e0d3864d977d'),
#   1656: ('biosphere3', '18ea247b-edc2-43fe-89bd-cedd04102bcc'),
#   3578: ('biosphere3', '18fb2184-d78e-467f-9eac-116bd534739f'),
#   3063: ('biosphere3', '19084123-7b31-4054-9afe-adc0dd20192f'),
#   552: ('biosphere3', '190d9910-5d04-4c97-abea-3b39682b7ed6'),
#   2471: ('biosphere3', '19108dfd-9b70-4fca-bac5-d523f8b5d3c0'),
#   2354: ('biosphere3', '1911896c-5aff-4695-9cba-164b0ecd9199'),
#   1184: ('biosphere3', '19256c0f-bea8-4e61-9499-8cc2f84953f8'),
#   3776: ('biosphere3', '195e0a29-e62d-47fc-b1f6-7155939e2b25'),
#   1959: ('biosphere3', '19696f8c-c5e9-4444-a0e8-3e8782748237'),
#   3433: ('biosphere3', '1982d665-0aef-4909-876a-f0e6b74220b8'),
#   590: ('biosphere3', '198ce8e3-f05a-4bec-9f7f-325347453326'),
#   427: ('biosphere3', '1992f951-d2c6-428d-9ff9-dac673f2b532'),
#   170: ('biosphere3', '19988f5b-a9a6-48f3-9e8e-150b66a1bf12'),
#   2802: ('biosphere3', '19b0229f-7cda-4154-baee-c1b1efef532a'),
#   2870: ('biosphere3', '19b55ff9-4964-45d1-95b6-e24d7f4ffbd3'),
#   754: ('biosphere3', '19b6e569-85a4-4ea9-a590-d61a21e3c846'),
#   3970: ('biosphere3', '19c48bf5-6116-5941-877a-ad23501dedb1'),
#   564: ('biosphere3', '19ca9276-e5c6-47f5-a3a4-18284d2a27c3'),
#   3974: ('biosphere3', '19d4089d-11a2-520c-84a0-b307ec625a0c'),
#   1219: ('biosphere3', '19e10755-75cf-4518-98c3-624201ac089f'),
#   78: ('biosphere3', '19e97bd6-d0ae-4208-bd77-d58e5d46d827'),
#   528: ('biosphere3', '19f84b2e-e6ff-4351-ba3a-8b650fc20d14'),
#   1515: ('biosphere3', '19ff96c2-6796-44e3-ab85-3635e8cb7e89'),
#   271: ('biosphere3', '1a13d6e7-45c9-427a-a3c9-38887ce7b86a'),
#   2360: ('biosphere3', '1a19ad61-abd0-4d42-9828-8fae315c0b06'),
#   819: ('biosphere3', '1a1d0d4b-6b95-4815-ad06-2ec5fe333c43'),
#   2973: ('biosphere3', '1a217018-e3e5-499c-9eb5-5aacb9e6ae9a'),
#   841: ('biosphere3', '1a568858-efa8-4c2a-b46e-82b6e66b6072'),
#   2307: ('biosphere3', '1a5850a0-0069-4b73-bb91-7a61e8d45ae5'),
#   2515: ('biosphere3', '1a6a1429-fd97-48cb-b7b7-3433f2fb16f9'),
#   1252: ('biosphere3', '1a796dc4-5dcb-40da-a609-3a5a40655fad'),
#   599: ('biosphere3', '1a7fba0e-91a3-4ac2-a58e-44575eeed078'),
#   353: ('biosphere3', '1aa7eec2-1079-4792-825c-364a7bde9921'),
#   895: ('biosphere3', '1aa8fd2e-9fbb-4701-8250-f4e31254b84a'),
#   919: ('biosphere3', '1acb026e-9de6-48fe-9e0d-be4d24125bbc'),
#   2692: ('biosphere3', '1ad3b0dc-fce4-416b-9851-f29d12cce55a'),
#   2713: ('biosphere3', '1ae07e12-290e-4ee2-a032-d3075e161c53'),
#   168: ('biosphere3', '1aee4aa7-32e0-48e7-a6b5-73d8acf672d3'),
#   74: ('biosphere3', '1af44724-172c-462b-b277-bb4b2fd32c33'),
#   4129: ('biosphere3', '1afd6f3b-1785-5093-a64d-aa7a89d752ba'),
#   4543: ('biosphere3', '1afedfb8-dfbd-4722-a5fc-f678c593d907'),
#   506: ('biosphere3', '1b0a8570-eab4-46c2-9b67-c9b918e75676'),
#   4509: ('biosphere3', '1b10a3a6-1168-5609-8d98-ed3252861869'),
#   3109: ('biosphere3', '1b279330-0469-4d04-9fe2-4e9a38011f0c'),
#   169: ('biosphere3', '1b35070a-eb57-4f0f-a27f-5ba181ff0d4d'),
#   3154: ('biosphere3', '1b454b03-a601-4d88-8c7c-21d971de9480'),
#   1088: ('biosphere3', '1b4810ed-4537-4cca-83ef-5af8a04668a7'),
#   965: ('biosphere3', '1b4da243-3412-4425-b44e-dea22e7ebd43'),
#   2998: ('biosphere3', '1b6a35b8-f6c8-404d-9c0e-e09b8fdb2d9e'),
#   3446: ('biosphere3', '1b7a743b-f3ab-4a26-9f83-7012ee6cc2f3'),
#   71: ('biosphere3', '1bb6a502-3ff9-4a79-835c-5588b855f1f5'),
#   3262: ('biosphere3', '1be475e0-ccef-4145-98e0-0d47c570a71b'),
#   739: ('biosphere3', '1be6f247-61bd-4614-a1fa-01a85e968fcb'),
#   657: ('biosphere3', '1c02cff4-e852-489b-893c-d3ed30eb8ca5'),
#   601: ('biosphere3', '1c0699e2-9be2-4c30-8328-fc0ad8caac58'),
#   2543: ('biosphere3', '1c321b9e-b832-4107-ada7-ef31cd78ceac'),
#   4638: ('biosphere3', '1c389e81-9f9d-4e52-a6e9-11cc6b73d90d'),
#   3058: ('biosphere3', '1c3c6032-1ed1-4e75-a2a9-af67850222b4'),
#   1345: ('biosphere3', '1c4a106a-53bc-40f5-bcae-d30ab191dbfe'),
#   4212: ('biosphere3', '1c51a129-9696-56e5-b18a-6f59edf07270'),
#   1159: ('biosphere3', '1c5a7322-9261-4d59-a692-adde6c12de92'),
#   4449: ('biosphere3', '1c84549b-9317-44b8-ad79-29c587e43bd3'),
#   4568: ('biosphere3', '1c8533e3-3781-5756-bd31-f3c32e820758'),
#   146: ('biosphere3', '1c87de06-e58f-4684-a54c-d29f1a251a87'),
#   3451: ('biosphere3', '1cb0b78b-6fd5-4193-8144-d47478920ced'),
#   4607: ('biosphere3', '1cc0be91-3df0-5d9b-ba9e-c0bb9ce30b0d'),
#   1018: ('biosphere3', '1ccc25c5-f5c0-4deb-b34a-965ccbaa4caa'),
#   982: ('biosphere3', '1cd24bc8-53b9-43e8-ad58-4438c9244a10'),
#   4240: ('biosphere3', '1cd8762b-d985-4206-b57e-f321e9b52399'),
#   3723: ('biosphere3', '1cde30ef-8a5b-46eb-9e7a-22a532fd6d2e'),
#   1778: ('biosphere3', '1ce92120-8acb-4e30-a97c-0b1ffd369b89'),
#   1239: ('biosphere3', '1d013cac-a0ec-4c02-936c-053afe24f47f'),
#   2414: ('biosphere3', '1d090e68-dd03-478b-82d4-09695ffc939a'),
#   4299: ('biosphere3', '1d0f4392-8c91-4d01-8a5d-f8fe1f5b05c9'),
#   1677: ('biosphere3', '1d2439de-751b-469a-ba3e-fda8fe9802b2'),
#   4127: ('biosphere3', '1d7cfaee-3ff0-5f72-abdb-bf15247fa36c'),
#   4353: ('biosphere3', '1d8560a8-23e0-57f0-ade2-69103c953de8'),
#   1437: ('biosphere3', '1d8ba55c-e60b-45ef-8e66-d947d8e7a01f'),
#   3556: ('biosphere3', '1dcae348-9373-4ff6-96f0-1a444fa96587'),
#   1496: ('biosphere3', '1dcf6b74-c474-420b-81ca-0b8d3d4f28d7'),
#   425: ('biosphere3', '1defe52a-bc9b-4c03-90fb-91bd35f6ce49'),
#   4318: ('biosphere3', '1dfb1f01-807b-5379-94f7-88e3ae421f57'),
#   1712: ('biosphere3', '1dfddbaf-11aa-4001-89e7-1303b3a95e02'),
#   4259: ('biosphere3', '1e060d5a-cd41-4f30-9c93-272403b7e004'),
#   4291: ('biosphere3', '1e19d86e-968d-4428-984f-70bfd843a8f4'),
#   1673: ('biosphere3', '1e2636dd-752e-4148-bdeb-d3e9abb4775e'),
#   855: ('biosphere3', '1e725387-0874-4acb-b026-11b30d76af56'),
#   4596: ('biosphere3', '1e7ae105-f032-4d62-b169-788cd6b9b384'),
#   2639: ('biosphere3', '1e904267-caa3-40e6-a3a0-fc104489770b'),
#   512: ('biosphere3', '1eaa9ea4-40b8-414a-b198-5626400372e1'),
#   3490: ('biosphere3', '1eb118df-d768-4084-b843-a1a04628e837'),
#   572: ('biosphere3', '1eb1b94c-e9d8-47ab-969b-9cca920157d8'),
#   222: ('biosphere3', '1eb38c24-2814-4c8e-bfdc-13467bab783c'),
#   1457: ('biosphere3', '1ec6c4b4-ee5f-4788-8683-c95a84d6d63c'),
#   2816: ('biosphere3', '1ed87d8c-afc2-47f1-af5a-df78ed6bad83'),
#   987: ('biosphere3', '1eefb686-03de-4dc8-933a-e3b7459438da'),
#   824: ('biosphere3', '1ef118e8-af9a-46d5-b04d-3ca10a69c51d'),
#   2673: ('biosphere3', '1ef5e6f5-06fb-41af-9f73-af85a3f0220d'),
#   23: ('biosphere3', '1f130425-11f9-4ec2-8d2f-d282acaacf5c'),
#   1237: ('biosphere3', '1f37ae35-463b-476c-9cde-d3e049fa7680'),
#   2237: ('biosphere3', '1f3c2297-d652-468d-82e8-4fd59bf5b5b8'),
#   2478: ('biosphere3', '1f455f6d-473e-4a50-af39-26dde8cd6479'),
#   995: ('biosphere3', '1f4afa32-a9a2-40da-8396-104452cb637f'),
#   1774: ('biosphere3', '1f5330ac-e81c-45f2-8c9c-335b531faab0'),
#   3189: ('biosphere3', '1f5c895e-f17c-4e2e-ba55-368273bdcf21'),
#   4315: ('biosphere3', '1f607ae2-b42d-4411-90b8-e9bbac66a554'),
#   1983: ('biosphere3', '1f8e9158-d59b-4991-872f-5a3f622979a7'),
#   4275: ('biosphere3', '1f96681c-1f2c-433e-8c60-45b66dc3ec01'),
#   4394: ('biosphere3', '1f9aba5f-035c-5f16-810e-5ab05083fe1d'),
#   2026: ('biosphere3', '1fa8ca7c-c285-49c5-a96d-60a3dc467310'),
#   3293: ('biosphere3', '1fc409bc-b8e7-48b2-92d5-2ced4aa7bae2'),
#   2684: ('biosphere3', '1fd12487-3082-4e34-b211-8ba77d1f51f6'),
#   494: ('biosphere3', '1fdc280a-34d3-4513-b110-3f526b17c443'),
#   2210: ('biosphere3', '1fdca295-07cb-4797-8fc8-2bd8ba79514f'),
#   4433: ('biosphere3', '1fe1cd2c-946d-5b0d-91af-3ed779fe42b3'),
#   2678: ('biosphere3', '1febb3ea-a4ee-4b7d-a6e7-0c4b6da28188'),
#   3733: ('biosphere3', '1fee3bdb-480b-4194-b3d7-0e4bd2814c33'),
#   1891: ('biosphere3', '1ff59fcb-f634-422c-bbbf-63dae44d9485'),
#   4688: ('biosphere3', '20185046-64bb-4c09-a8e7-e8a9e144ca98'),
#   1573: ('biosphere3', '201afd00-a74f-4ede-bbf7-770e39ed6471'),
#   1119: ('biosphere3', '20557d93-2b1c-49b5-b6c0-3528a8bbc307'),
#   1741: ('biosphere3', '205617ae-ebc5-4245-8df6-8710d5d40615'),
#   1771: ('biosphere3', '2058d91e-bb9f-4fce-8e53-131825b14a23'),
#   382: ('biosphere3', '20604bc5-214d-4883-97e3-9b43078c634b'),
#   2812: ('biosphere3', '2061c1e1-6a81-47ad-8a1d-81dd30783f2c'),
#   307: ('biosphere3', '20664d0e-24e3-4daa-8c5c-2ade6e0c2723'),
#   3771: ('biosphere3', '206b98e7-9df1-4aa1-896e-dc5aa93e9844'),
#   1386: ('biosphere3', '20750a37-320b-48cb-9fd4-366a86fcd6d6'),
#   301: ('biosphere3', '20834550-2d87-47d0-9d3c-fd65c108c72b'),
#   3474: ('biosphere3', '20839113-fbf2-4d2f-bab8-66861f86bc60'),
#   2621: ('biosphere3', '20a718fc-d376-4ca0-a7d5-a45026c936ab'),
#   2519: ('biosphere3', '20bc9500-2e2f-4cba-9332-8ea17d362aba'),
#   2525: ('biosphere3', '20c6c6d7-904c-4d33-923e-80e8ae7ee199'),
#   1647: ('biosphere3', '20d0fc73-b9ce-4001-ac15-893b30ed10a3'),
#   1500: ('biosphere3', '20d4d821-f4f7-4017-8810-f822fcdf619e'),
#   312: ('biosphere3', '20f74678-e826-4a98-a625-5b3e7bc7b9c1'),
#   2174: ('biosphere3', '2113ec49-2b48-4808-8e40-837769be8337'),
#   823: ('biosphere3', '211de86f-2e82-4a7a-acdb-0b72232f1fa3'),
#   2606: ('biosphere3', '21501e81-6395-4404-9cd6-001c6a686fd1'),
#   2948: ('biosphere3', '2169a4c1-3198-48ed-92f4-4fa22ed44739'),
#   3142: ('biosphere3', '21707ec1-bc38-4b1c-ac8b-0a2b3f7d5ec9'),
#   3432: ('biosphere3', '21806f1e-a21a-43f7-82b1-00dd5c42fe3f'),
#   3485: ('biosphere3', '2195d86f-e4c8-4e86-9f18-b5b065b1df7e'),
#   1854: ('biosphere3', '21ada84c-f5c9-49cc-9df1-0ca996091370'),
#   689: ('biosphere3', '21b46c65-491e-40a9-ac74-5877af997d7c'),
#   264: ('biosphere3', '21b5487b-4086-490b-9f98-1f5503feee7c'),
#   3273: ('biosphere3', '21c257b2-57ce-4a6e-b4bd-40f0f75f310f'),
#   661: ('biosphere3', '21dcb31a-fddb-464d-8d0d-4ce2738b2cb7'),
#   4705: ('biosphere3', '21e46cb8-6233-4c99-bac3-c41d2ab99498'),
#   2252: ('biosphere3', '21f77eaa-6f3e-426d-8932-fde33cd936d6'),
#   1483: ('biosphere3', '21f7d520-f329-4592-8880-949a08773371'),
#   109: ('biosphere3', '21f84442-7dc8-492a-8253-867dd1caf8d6'),
#   1933: ('biosphere3', '220257a9-c1c8-428d-8c35-db8b849d3db0'),
#   1504: ('biosphere3', '22043b06-1981-45a5-bfbb-20ae6f253191'),
#   4373: ('biosphere3', '2208ba07-373b-56a5-a2e3-8e770a4bc9a8'),
#   4203: ('biosphere3', '2213b951-1c93-5ae4-85b4-f4555a2dcd66'),
#   4066: ('biosphere3', '221d3aa1-6443-5d83-aad7-72929641bd0f'),
#   1338: ('biosphere3', '22317c8a-3b60-4479-8798-eec0bdfada2f'),
#   3960: ('biosphere3', '224c984f-5232-53d7-be57-5fece5b26323'),
#   1287: ('biosphere3', '22524a35-32c0-482a-82f7-49724ad1c595'),
#   4035: ('biosphere3', '2256a142-8242-4b4f-b9aa-a167803989ca'),
#   1384: ('biosphere3', '2256cd1c-760f-43b0-aa1c-5229ba199150'),
#   1807: ('biosphere3', '2257e9f9-f38c-494b-b99f-f49b4768b4b9'),
#   4523: ('biosphere3', '2260379b-c49f-553a-823c-565a71a797ec'),
#   2573: ('biosphere3', '2267ffd7-fe74-441e-873b-dd66c26a5e9f'),
#   1392: ('biosphere3', '22698b26-ab11-43eb-a48f-3e46863555cc'),
#   1912: ('biosphere3', '22798ed2-c8bb-42d5-8d7c-8e3b14d3bc3e'),
#   1396: ('biosphere3', '227f85d8-5156-461f-9d03-03960287debf'),
#   3310: ('biosphere3', '22a580a0-6674-4502-8a1c-b8ef9398a1db'),
#   1432: ('biosphere3', '22b0b296-d066-4159-a44b-69fdb17dc802'),
#   2215: ('biosphere3', '22b18b15-712c-4475-a6a3-e245da9252b6'),
#   2043: ('biosphere3', '22d1736f-baa9-481e-9583-42654a6a7c26'),
#   2328: ('biosphere3', '22d1d385-5aa4-404d-8c14-2680ce4accb0'),
#   3967: ('biosphere3', '22fbf3b0-06cf-53c7-b38b-64dfcdef37f8'),
#   1276: ('biosphere3', '22ff429e-4506-428d-9bba-4f9595ed3b99'),
#   3122: ('biosphere3', '230c08c9-70b7-4d28-a649-f5f85fbc3162'),
#   4700: ('biosphere3', '230d8a0a-517c-43fe-8357-1818dd12997a'),
#   3963: ('biosphere3', '231bcbc6-ce4d-5550-8244-9431031dea95'),
#   2438: ('biosphere3', '232b8aaa-06a6-4940-b725-46470bc82864'),
#   4227: ('biosphere3', '233ed5ca-7df0-4cf6-9271-21459ecd5c23'),
#   4029: ('biosphere3', '2354e2f3-5a4e-4d54-8183-4027fb64c4eb'),
#   1947: ('biosphere3', '235b2f02-ff98-4da9-82e2-e4246c7b7990'),
#   223: ('biosphere3', '237a5f15-8119-472a-8988-88b7ecb42405'),
#   2202: ('biosphere3', '237ca6bc-2f0a-4416-a0e3-bd512f038f2e'),
#   68: ('biosphere3', '237ea455-6c82-4254-af86-9409df922094'),
#   1868: ('biosphere3', '23856318-9583-426b-ab04-12e4506b60a8'),
#   2342: ('biosphere3', '23868338-42bc-4baf-a9e2-8e84ff8c92f1'),
#   329: ('biosphere3', '238f8ea9-98df-41dc-ab93-ea5b549a0b96'),
#   4582: ('biosphere3', '23945e60-7980-57ee-882d-ed0dbf2b201b'),
#   3661: ('biosphere3', '23a4dfc7-c82e-4425-abf6-0195f78f3363'),
#   1629: ('biosphere3', '23a9f33d-dbab-4fcc-8f49-1df731b0b827'),
#   3545: ('biosphere3', '23b6a72b-f926-40e3-b88a-0fb565d36de1'),
#   3120: ('biosphere3', '23c39061-9fdb-4753-8aaa-893a8cad4a4e'),
#   3069: ('biosphere3', '23cb10a4-6228-4ce4-9fb5-7043bc31faec'),
#   2829: ('biosphere3', '23dedce6-fc17-4ae8-9b91-6c0dca431adc'),
#   929: ('biosphere3', '23e83c1f-07c9-4b5f-a898-0f4f09a6691f'),
#   1157: ('biosphere3', '23eaa36d-add4-4219-961e-ca7104dc0de9'),
#   218: ('biosphere3', '23f4021a-5b2d-4e16-ba87-76e871b32392'),
#   4021: ('biosphere3', '240177d8-6f3b-43f5-8d1e-0c18114dfa02'),
#   3613: ('biosphere3', '2404b41a-2eed-4e9d-8ab6-783946fdf5d6'),
#   3675: ('biosphere3', '240ca121-d614-45f7-98fb-e6891559a4d0'),
#   3335: ('biosphere3', '24145938-f9e3-40ea-ab06-409187ca5d26'),
#   2500: ('biosphere3', '242b4a08-f6ff-496d-ae0f-bf8f8bc77692'),
#   1473: ('biosphere3', '2451f9df-0596-49ec-8380-08e4ad75a153'),
#   1492: ('biosphere3', '24541c8c-9f11-49ae-9de5-456f238a3f5e'),
#   1561: ('biosphere3', '24594cef-c50b-4e02-a5e3-c40cb06fea18'),
#   1593: ('biosphere3', '2460f868-54a9-404c-bec8-c809a44ae72c'),
#   3004: ('biosphere3', '2460ff3a-b368-4224-9c0d-0900fd29608f'),
#   1654: ('biosphere3', '246c87af-4495-4977-8d39-eae397c1c8f1'),
#   3829: ('biosphere3', '24752b90-cc53-4198-a442-14196853148d'),
#   132: ('biosphere3', '247ac273-60fa-4e21-9408-793f75fa1d37'),
#   829: ('biosphere3', '247ddc2a-c861-43be-97f0-0183e3d12f99'),
#   4061: ('biosphere3', '247f3d96-7da2-5adf-a399-65745bc042fb'),
#   1455: ('biosphere3', '248223f5-4e00-4b0d-9652-76a9c39ce414'),
#   4416: ('biosphere3', '24a29bd2-ec92-5fd1-adea-f763a63bea78'),
#   2971: ('biosphere3', '24acc516-974c-4ff3-b7e1-5950b8d37206'),
#   1080: ('biosphere3', '24cf82f8-c517-4fef-8f93-17519adb855e'),
#   585: ('biosphere3', '24d49070-45df-4627-84fa-2d8adeca255b'),
#   1591: ('biosphere3', '24da5f03-1b1e-4a60-a925-248122c9d2a0'),
#   2488: ('biosphere3', '24e0a9cb-a789-46e2-a25c-0278a90d67e5'),
#   783: ('biosphere3', '24edeb85-2af8-4477-b064-1cdcf1510449'),
#   2743: ('biosphere3', '250dd08a-ee61-4a2b-86f8-b21e9ebe6ed9'),
#   2584: ('biosphere3', '25131632-4b24-4625-8940-60d00385dad5'),
#   2532: ('biosphere3', '251ad87f-5bfb-4eb5-8a00-5050e1782263'),
#   2686: ('biosphere3', '251b1db4-29e6-4312-bc30-ef7ae34aaaa3'),
#   4405: ('biosphere3', '25468a1a-688a-5e17-941c-bba695ec828e'),
#   3032: ('biosphere3', '25577c13-5625-41cf-a921-9e82f81d2131'),
#   1701: ('biosphere3', '2563243b-9991-4fb4-bfe7-4239c25de7db'),
#   1426: ('biosphere3', '2566a811-5c71-4cef-9c90-cd3840cd707b'),
#   4379: ('biosphere3', '25755c25-615b-546b-af93-257e82ba2f5a'),
#   348: ('biosphere3', '257eacb9-96fe-4a3d-961a-f5e6c7823ff0'),
#   1607: ('biosphere3', '258263a0-6be3-4439-bd84-efee0498b849'),
#   3717: ('biosphere3', '259cf8d6-6ea8-4ccf-84b7-23c930a5b2b3'),
#   1399: ('biosphere3', '25f52995-fc88-44ab-b11c-f93e35020d01'),
#   4488: ('biosphere3', '2612a99d-0ea4-547c-a66b-5d6a27637186'),
#   2618: ('biosphere3', '26202571-16f9-48c3-bf4d-e9c189f43b2c'),
#   275: ('biosphere3', '26296ec9-ff93-41e6-bbbf-6175af04284d'),
#   3903: ('biosphere3', '262ae9a3-596c-50cc-8cb4-29663f758d7f'),
#   180: ('biosphere3', '26328cc0-eaef-49b4-9c42-2396313bbb5e'),
#   2905: ('biosphere3', '2635ffda-08c1-4069-b130-25f11c3db05d'),
#   3871: ('biosphere3', '2649e223-09c0-5ced-9604-6cd6332e7cf9'),
#   4399: ('biosphere3', '26596915-25f4-5b8a-8673-af6daead169d'),
#   4503: ('biosphere3', '2668faa0-1e97-513e-9333-684814cf181b'),
#   1623: ('biosphere3', '26991da1-c263-4707-9f85-78685acc94dc'),
#   1890: ('biosphere3', '26997b2a-7acf-445b-b07e-d6736fd4ac81'),
#   453: ('biosphere3', '26b5c174-e20e-430a-a4b1-44de4af8b40f'),
#   3863: ('biosphere3', '26e10723-d896-54ec-ab5b-5a4804d2f9ba'),
#   2363: ('biosphere3', '26eb22d8-e0cf-45a6-b09e-b8609fe6c8eb'),
#   547: ('biosphere3', '26efe47c-92a5-4dea-b4d0-eac13e418a58'),
#   2540: ('biosphere3', '2712fe5f-0d3c-4c8e-8bc4-26c604413849'),
#   434: ('biosphere3', '2716807d-0266-48ff-bb7a-6e6c5fbfd5c5'),
#   1577: ('biosphere3', '2718482b-8399-442e-b89a-52fbcc22d2e6'),
#   734: ('biosphere3', '273b51ae-dcc4-45c6-b8da-f6ba0313edf8'),
#   4483: ('biosphere3', '2759c5ea-c684-5b4a-94ca-9a448bd78159'),
# ...
#   1623: ('biosphere3', '26991da1-c263-4707-9f85-78685acc94dc'),
#   1890: ('biosphere3', '26997b2a-7acf-445b-b07e-d6736fd4ac81'),
#   453: ('biosphere3', '26b5c174-e20e-430a-a4b1-44de4af8b40f'),
#   3863: ('biosphere3', '26e10723-d896-54ec-ab5b-5a4804d2f9ba'),
#   2363: ('biosphere3', '26eb22d8-e0cf-45a6-b09e-b8609fe6c8eb'),
#   547: ('biosphere3', '26efe47c-92a5-4dea-b4d0-eac13e418a58'),
#   2540: ('biosphere3', '2712fe5f-0d3c-4c8e-8bc4-26c604413849'),
#   434: ('biosphere3', '2716807d-0266-48ff-bb7a-6e6c5fbfd5c5'),
#   1577: ('biosphere3', '2718482b-8399-442e-b89a-52fbcc22d2e6'),
#   734: ('biosphere3', '273b51ae-dcc4-45c6-b8da-f6ba0313edf8'),
#   4483: ('biosphere3', '2759c5ea-c684-5b4a-94ca-9a448bd78159'),
#   2490: ('biosphere3', '276e755c-ed57-466a-b555-4658c791f385'),
#   1441: ('biosphere3', '27804c78-5eee-47f9-9a91-1f6126ccfe45'),
#   276: ('biosphere3', '27b0b1f4-8cd4-4277-bfdd-1cab2f9c5e1c'),
#   1270: ('biosphere3', '27c1a9a6-c45e-431f-830b-7061a100fed7'),
#   3524: ('biosphere3', '27d03876-622e-4951-8547-ce331b7d3521'),
#   3384: ('biosphere3', '27d2b49d-9ecb-4b0a-80dc-9c6598464c6a'),
#   2377: ('biosphere3', '27db07bb-7d5b-4e63-8f16-401781188148'),
#   252: ('biosphere3', '27f61651-96a5-45c7-9873-832626cf6905'),
#   2915: ('biosphere3', '27f767b3-3ab6-41bd-9c5f-524104b23dce'),
#   4524: ('biosphere3', '27fbdcf1-7eed-561b-b328-38b8f2427fc8'),
#   1092: ('biosphere3', '2813518d-c4a8-4a8d-9542-f1882ec27c1c'),
#   1376: ('biosphere3', '281e1011-f121-4d5b-ad4d-22d562b2c2cd'),
#   193: ('biosphere3', '282973e4-3c2d-4a9c-a3f2-d39a5b36aa76'),
#   2932: ('biosphere3', '282d4a11-f053-47cf-89a4-aafa3184d61d'),
#   4160: ('biosphere3', '282eeb45-e6b8-5bf1-9010-316fb20b87d9'),
#   1185: ('biosphere3', '284a896f-2aca-496e-9ab2-845525fbbc53'),
#   1445: ('biosphere3', '284d6491-de2c-4124-95db-7732cbb5136c'),
#   1029: ('biosphere3', '285188e4-9b50-4916-a2bd-e7ce44354a88'),
#   927: ('biosphere3', '28528881-7154-48d5-9cc3-5c13ddcdc47a'),
#   1922: ('biosphere3', '2853753b-084a-4962-bc19-c32d3a52ac2d'),
#   1818: ('biosphere3', '28677a43-a849-4e4b-9504-58b7c07b25ed'),
#   1600: ('biosphere3', '28955c40-9925-47d2-9770-dc18a4bba82a'),
#   1099: ('biosphere3', '28999907-a8a7-45b3-857e-836495ca2aa0'),
#   2371: ('biosphere3', '28b0681a-8e83-4997-be31-65e5a0a1a81f'),
#   3454: ('biosphere3', '28b4d99e-6111-4ef9-8c34-10f94fff9309'),
#   933: ('biosphere3', '28b7568a-4238-47ff-8b95-2b97ba55c6f3'),
#   3327: ('biosphere3', '28bca51a-6cc7-46af-961a-fd2b675a1376'),
#   1545: ('biosphere3', '28be1d65-6b09-4ebd-8599-4366c3c2abab'),
#   1165: ('biosphere3', '28e1e2d6-97ad-4dfd-932a-9edad36dcab9'),
#   217: ('biosphere3', '28f19625-5e6a-4902-8c18-4b519db19d86'),
#   3128: ('biosphere3', '28febdb5-59ae-41c3-8709-43edb165f74e'),
#   3478: ('biosphere3', '29190509-6cc8-47e1-bc99-5ff994e39b74'),
#   514: ('biosphere3', '2925111b-3464-4e34-9d02-b73c1c033e91'),
#   1596: ('biosphere3', '295060ba-3c3d-45e4-99ca-e17b1204b553'),
#   4187: ('biosphere3', '29520fb9-bf5b-577d-a398-22e87cf168bc'),
#   4706: ('biosphere3', '295c9740-6fdb-4676-9eb8-15e3786f713d'),
#   818: ('biosphere3', '29630a65-f38c-48a5-9744-c0121f586640'),
#   3174: ('biosphere3', '297cc04f-e215-433c-ae3b-d1e34464c785'),
#   3644: ('biosphere3', '299c6564-426e-48c3-b516-fdf301d12127'),
#   4699: ('biosphere3', '299f371a-61c1-4ea2-8c38-901aa74acf7d'),
#   3518: ('biosphere3', '29bb09a9-cfef-419e-8322-88e2f6bc0558'),
#   1864: ('biosphere3', '29bfab29-0ad0-47da-b5b9-a76328ba5a64'),
#   3941: ('biosphere3', '29ed3a9c-84ee-530d-8ba7-bf8e0d2fe754'),
#   1520: ('biosphere3', '29f7aad7-40e1-44db-af21-b3604c10b3f0'),
#   154: ('biosphere3', '29fba89c-b900-4160-a5f1-129916933bca'),
#   3621: ('biosphere3', '2a042136-80fd-4c1c-8996-65a7985497d3'),
#   741: ('biosphere3', '2a1c80de-a083-470b-80dd-ba11a5aeea8c'),
#   3782: ('biosphere3', '2a46d676-6d14-4541-8cbf-e29d9996c76d'),
#   3406: ('biosphere3', '2a46e7f4-c66c-43e5-8a8a-d119c4098aff'),
#   1387: ('biosphere3', '2a51889e-9264-45df-9753-64c25a755d9e'),
#   1222: ('biosphere3', '2a5ed451-12a2-47db-b4dc-fa0bfbc01d79'),
#   2710: ('biosphere3', '2a613b0f-cc83-4039-aebb-1e95810ec106'),
#   4496: ('biosphere3', '2a791f06-6a52-54e3-87af-8dec4d03198c'),
#   2055: ('biosphere3', '2a7b68ff-f12a-44c6-8b31-71ec91d29889'),
#   3277: ('biosphere3', '2a8ec77d-55f2-402a-bc5a-2e9162de2822'),
#   3403: ('biosphere3', '2a992e5e-9f16-47b8-8bcb-733d00bed658'),
#   2940: ('biosphere3', '2b178c09-89d4-49be-afbb-ec21bc158d9c'),
#   3160: ('biosphere3', '2b185e1c-282d-40df-86c9-99de81830782'),
#   2158: ('biosphere3', '2b2369a4-26bb-4b18-8479-752fdf7a5e7f'),
#   3818: ('biosphere3', '2b3cf153-0dd6-4b79-b0d4-b4df832f3a7e'),
#   1236: ('biosphere3', '2b4a3249-b67a-4858-abf7-24aa1468f298'),
#   1045: ('biosphere3', '2b50f643-216a-412b-a0e5-5946867aa2ed'),
#   1986: ('biosphere3', '2b676e9e-1e3b-45d6-b209-6ed3af61fc42'),
#   3628: ('biosphere3', '2b6c2cee-deb2-49f1-a552-a666a41fc14e'),
#   3841: ('biosphere3', '2b8204fa-c9bf-5465-9aa2-d79024a19b1a'),
#   519: ('biosphere3', '2b8a0f87-bd2a-4b10-8dd9-714487f59fc9'),
#   4089: ('biosphere3', '2ba5e39b-adb6-4767-a51d-90c1cf32fe98'),
#   4372: ('biosphere3', '2ba6c345-1a1c-5337-b547-1753ea269581'),
#   2152: ('biosphere3', '2baa4381-b781-4f5e-90de-508b0fa3fd1f'),
#   1965: ('biosphere3', '2bb2d63d-ad12-442f-af58-009b08ce2df4'),
#   3226: ('biosphere3', '2bbffe32-86bd-485c-95a2-844bbfd42840'),
#   2243: ('biosphere3', '2bcad3b3-5305-481c-a166-ad5e6eac2675'),
#   3407: ('biosphere3', '2beb46d1-2d1d-48ca-bf95-f0668fed29bf'),
#   308: ('biosphere3', '2becddd1-aa5a-4c35-be0e-aefb9bd469f8'),
#   4271: ('biosphere3', '2bf2965d-d5ce-5e65-ad9d-b0b636c70b20'),
#   448: ('biosphere3', '2bf4e40e-ed11-457a-ae60-53a5cc43fdc7'),
#   797: ('biosphere3', '2c126bcc-bb63-4d63-bd72-f02a1e616809'),
#   3987: ('biosphere3', '2c25d5de-bb2f-5fff-bb42-f7177e88e84e'),
#   4499: ('biosphere3', '2c43033a-5567-5a95-aa61-fd637d38dd2a'),
#   2402: ('biosphere3', '2c5362e9-ff22-46b4-9dad-3c765df0ac3f'),
#   2644: ('biosphere3', '2c668435-93b1-4a68-8b7c-f32f65615d37'),
#   4502: ('biosphere3', '2c79c4ee-6e76-5c59-a4c1-4dbdb674bc56'),
#   3487: ('biosphere3', '2c7be02c-791f-4fef-b231-b90321bbeb30'),
#   2635: ('biosphere3', '2c86a9d8-2cd6-409a-8e5c-86fc3b52bf97'),
#   2457: ('biosphere3', '2c872773-0a29-4831-93b9-d49b116fa7d5'),
#   2557: ('biosphere3', '2c931139-2463-4abd-9dc0-3523477499db'),
#   2929: ('biosphere3', '2c9a7182-37c8-4777-a37a-9a007c3edb2f'),
#   1940: ('biosphere3', '2c9e7fba-dd57-4294-8a5e-2aa489930f69'),
#   4034: ('biosphere3', '2caa889e-8187-459d-963a-fa47a79c5378'),
#   1179: ('biosphere3', '2cb2333c-1599-46cf-8435-3dffce627524'),
#   865: ('biosphere3', '2cb441cd-8d2e-4e5c-a208-48c4fa005c41'),
#   910: ('biosphere3', '2cba713d-ab0b-44cb-babb-f8cac262554f'),
#   76: ('biosphere3', '2cbb504a-ce2f-40e9-9d38-e130e95a1242'),
#   1357: ('biosphere3', '2cbc6042-2cee-4668-8017-d7f805d9029e'),
#   310: ('biosphere3', '2cbe35d9-052c-4fe8-8eb2-08769f10b2c7'),
#   2131: ('biosphere3', '2cbfe861-7436-4a43-8892-f057320dc57d'),
#   694: ('biosphere3', '2cc8dc8a-e6fb-4486-a840-4bdc1bc71e9b'),
#   2180: ('biosphere3', '2cc93e0a-c655-4628-bea6-243d8240b5a4'),
#   2497: ('biosphere3', '2ce73c7e-01b7-4fc0-a995-0e3785d5277d'),
#   1929: ('biosphere3', '2cea4705-5460-4f03-80ca-1aaf90f17c3a'),
#   2141: ('biosphere3', '2cf249bc-1557-41e1-81e8-866d06e3413c'),
#   4578: ('biosphere3', '2cf2c41e-3980-529a-ab58-872e32914fbb'),
#   1056: ('biosphere3', '2cfb7e90-7484-48e3-9885-a7f097965ec3'),
#   2966: ('biosphere3', '2cfc5ba4-3db2-4193-9e81-b61e75ba1706'),
#   3110: ('biosphere3', '2cfcbe85-0dfd-4414-8683-ecc74392346c'),
#   2888: ('biosphere3', '2cfea267-9965-411e-9381-4d32835b4ffe'),
#   4589: ('biosphere3', '2d1288bb-5b04-5f1d-a707-f94a3e826b95'),
#   1411: ('biosphere3', '2d17bb2f-2072-4a7a-a672-9550a97c14f5'),
#   1984: ('biosphere3', '2d456fb8-592b-46a7-97f0-81fc2a18e587'),
#   3141: ('biosphere3', '2d4b8ec1-8d53-4e62-8a11-ebc45909b02e'),
#   1474: ('biosphere3', '2d50f4c8-a917-4496-a7d9-470b080faf68'),
#   323: ('biosphere3', '2d65a3f7-2a10-4a10-ac9e-a0cc7cd57979'),
#   2774: ('biosphere3', '2d8f3c1b-8965-4f5c-9d66-72148d9af9ba'),
#   2949: ('biosphere3', '2d97af62-5de1-4105-8e35-23604c1e9a3e'),
#   3702: ('biosphere3', '2d9f9c6b-8dca-4641-8ff9-53cb8beabd13'),
#   2341: ('biosphere3', '2df5a2fe-1ab2-48e7-a9a6-1085703b17be'),
#   2066: ('biosphere3', '2df9d4e0-f095-4089-be46-1c1acbcf3a09'),
#   1109: ('biosphere3', '2dfff11a-db89-40be-a64c-83db726cc1be'),
#   791: ('biosphere3', '2e002771-9f22-43e3-9990-f06f8235700b'),
#   2408: ('biosphere3', '2e0c9efa-d55c-49db-8be3-0376d5921ff4'),
#   1394: ('biosphere3', '2e1396a2-b8e0-4f4a-89c7-11c4ee4733c1'),
#   32: ('biosphere3', '2e18b480-7449-4800-85bd-c8ad0e649c03'),
#   2741: ('biosphere3', '2e1ac281-307a-409d-9b75-abd4db38a1e0'),
#   2782: ('biosphere3', '2e2a9226-1d5a-4adf-aa0f-6a4b9499e8d7'),
#   2790: ('biosphere3', '2e2c0b46-41cf-4be8-9a92-246aecc58608'),
#   128: ('biosphere3', '2e3da68d-e404-4377-bce9-b35244980811'),
#   2080: ('biosphere3', '2e518059-747c-4ff1-8da3-17134c547ac2'),
#   936: ('biosphere3', '2e51caef-d635-4d0d-bcee-fb0c58fa5435'),
#   834: ('biosphere3', '2e52cbfa-94d7-432b-892f-431daa71a6ef'),
#   652: ('biosphere3', '2e704527-1e5f-49d0-a2e9-e6d10d52d6e4'),
#   616: ('biosphere3', '2e718246-b4f2-44e3-bcc5-2ce3496d2db6'),
#   3276: ('biosphere3', '2e7b6bd9-c3af-498f-8d33-b172fc82c688'),
#   1241: ('biosphere3', '2e969e9b-f2e9-4fcc-8962-13a755dc8302'),
#   2015: ('biosphere3', '2e972b23-f14e-477d-9360-7a88a35f0501'),
#   1898: ('biosphere3', '2eb231c3-447f-42e3-bcb6-fdcbdb8ee915'),
#   3067: ('biosphere3', '2ec209eb-22f1-47ca-8d32-c11dc4a92d0d'),
#   2225: ('biosphere3', '2ef1d3db-baba-4948-bd9c-eb91e4a36228'),
#   2908: ('biosphere3', '2ef56ffc-fa69-4b57-a936-3d588923ea8b'),
#   4095: ('biosphere3', '2f033407-6060-4e1e-868c-9f362d10fdb2'),
#   1784: ('biosphere3', '2f052025-4072-4d8e-b22d-68d50bfb260c'),
#   3083: ('biosphere3', '2f19a0af-a516-4f89-88ba-4c6b7cd52650'),
#   2837: ('biosphere3', '2f1d0962-be5d-4e6d-9c9b-0846722d9c65'),
#   835: ('biosphere3', '2f1e926a-ec96-432b-b2a6-bd5e3de2ff87'),
#   3201: ('biosphere3', '2f2450fa-6720-4b59-9876-10a9ee843958'),
#   4383: ('biosphere3', '2f298808-c928-5f94-af08-c405cd38901a'),
#   2582: ('biosphere3', '2f34359c-ba87-42d9-8be4-4f38b6d5af37'),
#   3367: ('biosphere3', '2f36d881-55bd-44ed-a383-a97cd4c53b16'),
#   906: ('biosphere3', '2f38ead0-f60f-4a9b-a7ca-31219c1a2f65'),
#   3260: ('biosphere3', '2f6bb945-2e93-4ea8-b3b6-7930c3680486'),
#   891: ('biosphere3', '2f885055-6517-4930-a649-dbf008f02910'),
#   2255: ('biosphere3', '2f8952b0-c90c-4e3d-b546-52b862fc8f11'),
#   1495: ('biosphere3', '2fd1f829-b1c3-4464-bc13-315d40387228'),
#   1746: ('biosphere3', '2fdf4d27-d787-4a48-9e8e-8cbd79246c74'),
#   3972: ('biosphere3', '2fee2825-acaa-562e-8611-e607b8f94fcc'),
#   3598: ('biosphere3', '2ffd03dc-a8df-467d-a362-b1f9f3136abc'),
#   1126: ('biosphere3', '2ffd26c6-0d3d-4379-9da2-2b578807a14b'),
#   1359: ('biosphere3', '2fff3bda-1eec-4166-9969-bc9e757c8e8e'),
#   3112: ('biosphere3', '300bed66-a3c8-46cf-92c2-92d28dff9f91'),
#   4047: ('biosphere3', '3048af84-1d72-5e3f-a739-b2d7fa7d4773'),
#   1367: ('biosphere3', '30533fd3-b19c-44fc-9a88-fb6b12409b47'),
#   2944: ('biosphere3', '30614997-3952-4e2a-bde2-4bce2cada098'),
#   4131: ('biosphere3', '307b8a08-71a0-5505-8a95-edc92d9fadf8'),
#   4597: ('biosphere3', '30a6dd59-5d2b-5c4c-a6a3-9a3bd8ded2c9'),
#   4514: ('biosphere3', '30c14720-e0b4-5980-b00e-eeb17da5d226'),
#   4377: ('biosphere3', '30d74b5c-a7a1-5666-9582-a48aae195c75'),
#   619: ('biosphere3', '30e130e0-ff90-4e07-9cda-c53b81e0bbe6'),
#   2632: ('biosphere3', '30f484ee-dec4-47ae-8e92-d00d4b93fe05'),
#   466: ('biosphere3', '30fed59d-d722-482f-be4f-f3d93bdd2527'),
#   4581: ('biosphere3', '310a744b-7a1a-5b7a-a68b-7e85de9d8a20'),
#   3853: ('biosphere3', '3135755c-1082-5c68-9290-55b858fd7ff2'),
#   1436: ('biosphere3', '313cdf6d-ac44-4583-87a1-5f2ba3413a88'),
#   3512: ('biosphere3', '31417daa-cd7a-4920-9c73-708b68d494ad'),
#   14: ('biosphere3', '3166d308-cc57-4d31-b42e-63c7eada821f'),
#   4352: ('biosphere3', '317c9f65-0142-5fa0-99da-98a5c7d639dd'),
#   2455: ('biosphere3', '3184c902-c587-4fd7-bd89-769d3cf30072'),
#   3108: ('biosphere3', '3189f4ab-348e-4207-be3d-59c2b6f8a63f'),
#   229: ('biosphere3', '31913320-21f3-4cc2-b09a-a15ac9b65f5e'),
#   173: ('biosphere3', '31998285-fb5c-411d-b853-ce78be2a0b49'),
#   435: ('biosphere3', '31a3e44c-4098-461e-aba2-f79540e05087'),
#   1533: ('biosphere3', '31a4ca5f-abb9-4dc8-a16f-116c584d4f96'),
#   67: ('biosphere3', '31b12a79-5555-4eb6-8cae-4b13b53ef8af'),
#   755: ('biosphere3', '31b4eea9-640e-4056-ac2f-0555627af18a'),
#   2473: ('biosphere3', '31ba993d-f8aa-44c0-bae1-b6c2081144f6'),
#   2961: ('biosphere3', '31c4d160-b21e-41b3-b9c1-3d7a72377653'),
#   603: ('biosphere3', '31cda69b-c54e-4f82-a88d-e01c1c7fff2b'),
#   4531: ('biosphere3', '31d6cf74-5677-5e76-830d-02d214cbdb2d'),
#   804: ('biosphere3', '31e4e26b-a997-4969-963d-243699aca3a8'),
#   3323: ('biosphere3', '31eacbfc-683a-4d36-afc1-80dee42a3b94'),
#   4529: ('biosphere3', '31f72435-fdbb-5dac-9887-c3ae1d92dd4b'),
#   1638: ('biosphere3', '31f8976a-6f7d-487e-a850-eb495dbf0351'),
#   3448: ('biosphere3', '3209b4a6-9e83-42f3-afad-39c62dc2d333'),
#   2988: ('biosphere3', '32299af9-3432-470b-8f90-5d06df12b062'),
#   2287: ('biosphere3', '32451556-ee07-4e36-bd8a-09f8847f9c83'),
#   2466: ('biosphere3', '324c68b1-5c09-4080-bb88-dd8b6c0f796d'),
#   636: ('biosphere3', '3250f566-58bc-46d3-ab88-1d2e23ca3e1b'),
#   3652: ('biosphere3', '3268d8df-59cc-4740-a89f-dee8355ad7c3'),
#   981: ('biosphere3', '326b94e8-aea0-4bd4-8a50-63bf283882a8'),
#   2600: ('biosphere3', '327212ad-eac9-49f2-afc3-26520e60c951'),
#   3190: ('biosphere3', '3277a622-8234-4c73-ba22-526cf9a0fccc'),
#   3442: ('biosphere3', '3277c200-21e3-4b45-8dcc-97cdc2e4c245'),
#   4573: ('biosphere3', '329d57e1-1ca2-5df0-a83b-a78b8955585b'),
#   587: ('biosphere3', '329fc7d8-4011-4327-84e4-34ff76f0e42d'),
#   181: ('biosphere3', '32aaf6ef-c3e7-4c81-8e37-4c3c8768454f'),
#   1296: ('biosphere3', '32bd196f-401c-4ece-bc45-a3b5ab7fd6fc'),
#   4266: ('biosphere3', '32cd0492-c0cb-4898-a2b1-675eedc5b688'),
#   1113: ('biosphere3', '32d98afc-e42b-46f6-b53e-9c949875ab20'),
#   3377: ('biosphere3', '32fccda4-0d99-40ab-b65f-c7203080b62b'),
#   3601: ('biosphere3', '3301e59e-2f7b-46bd-b185-32ef8caac4ea'),
#   3328: ('biosphere3', '33130fd7-3a99-437a-b179-33ea64ca1f9d'),
#   4358: ('biosphere3', '33141a63-6572-5eca-9500-8f67bc664746'),
#   2925: ('biosphere3', '332a3e5f-39c6-4336-9064-13276942fbba'),
#   3563: ('biosphere3', '334548b2-e05c-4e7b-9746-c27dd2aaa58c'),
#   471: ('biosphere3', '33456751-d78b-465d-8635-52d71e77cf54'),
#   2297: ('biosphere3', '334f3d29-ec7d-4ca4-9e65-524c64c6649c'),
#   2642: ('biosphere3', '33627701-feca-434d-a192-674a450eaaf7'),
#   1664: ('biosphere3', '33681770-a0e1-4ce8-93c3-941fd607fa5f'),
#   1823: ('biosphere3', '336fca6f-2dc9-4514-96ae-2a2af154c74e'),
#   1198: ('biosphere3', '339edacb-b552-4ac4-b5ed-db6192e1925a'),
#   443: ('biosphere3', '33a69662-583b-45b8-8cb9-94f59fca9133'),
#   1646: ('biosphere3', '33a791a2-a1e7-446b-b25a-b3be6159bae4'),
#   2270: ('biosphere3', '33aaa517-2f57-4b13-be01-910469b03567'),
#   1752: ('biosphere3', '33b38ccb-593b-4b11-b965-10d747ba3556'),
#   4378: ('biosphere3', '33c162f4-1211-53c8-a2cf-b2428f096388'),
#   52: ('biosphere3', '33d0fe96-541c-4ac2-9dd6-51b44dc39676'),
#   4175: ('biosphere3', '33d1cc99-8dbd-5c0f-8aba-7fa362cca070'),
#   369: ('biosphere3', '33fd8342-58e7-45c9-ad92-0951c002c403'),
#   3224: ('biosphere3', '33fe9178-c7f7-4ebe-950a-8cbd1e799424'),
#   2065: ('biosphere3', '3400c608-5098-4f36-8d72-e5a20e0a5c39'),
#   4128: ('biosphere3', '340aa83e-9594-5819-9e0e-d149bec71bcf'),
#   473: ('biosphere3', '340eb8e4-5282-4862-8840-35fcc50e3505'),
#   26: ('biosphere3', '3410aa09-a803-4bdc-8f10-f03f1760851a'),
#   2405: ('biosphere3', '34550110-0552-46d2-b07d-6b9599892278'),
#   1291: ('biosphere3', '34698efa-71c8-4fec-9a43-6529f45887ac'),
#   2082: ('biosphere3', '347de5bf-3551-4022-8371-258e830b5a09'),
#   343: ('biosphere3', '34837fe3-4332-493c-86bb-95a207d9c234'),
#   1535: ('biosphere3', '349a76e2-a467-439f-a179-76d16b656ed1'),
#   3920: ('biosphere3', '349ae04f-3802-53d3-840e-a98334b3e3ba'),
#   1171: ('biosphere3', '349b29d1-3e58-4c66-98b9-9d1a076efd2e'),
#   2430: ('biosphere3', '34b96163-a3df-4bc1-8224-e2a9fe01b23f'),
#   ...}}

# %%
for i in data_objs:
    print(i.metadata["name"])
# Out:
# biosphere3
# ecoinvent-391-cutoff
# asphalt
# cml-v48-2016cg.231d6e8f8b1c199a47182515eba4032e.zip

# %%
dp_lca = bc.LCA(demand=indexed_demand, data_objs=data_objs)
dp_lca.lci()
dp_lca.lcia()
dp_lca.score
# Out:
# 0.15512695599913062

# %%
biosphere_dp = [dp for dp in data_objs if dp.metadata["name"] == "biosphere3"].pop()
biosphere_dp.metadata["name"]
# Out:
# 'biosphere3'

# %%
ei_dp = [dp for dp in data_objs if dp.metadata["name"] == EI_DB_NAME].pop()
ei_dp.metadata["name"]
# Out:
# 'ecoinvent-391-cutoff'

# %%
fg_dp = [dp for dp in data_objs if dp.metadata["name"] == "asphalt"].pop()
fg_dp.metadata["name"]
# Out:
# 'asphalt'

# %%
pprint(fg_dp.metadata)
# Out:
# {'combinatorial': False,
#  'created': '2024-04-02T17:03:07.471365Z',
#  'id': '3494d9184720464492206de1a498989d',
#  'licenses': [{'name': 'ODC-PDDL-1.0',
#                'path': 'http://opendatacommons.org/licenses/pddl/',
#                'title': 'Open Data Commons Public Domain Dedication and '
#                         'License v1.0'}],
#  'name': 'asphalt',
#  'profile': 'data-package',
#  'resources': [{'category': 'vector',
#                 'format': 'npy',
#                 'group': 'asphalt_inventory_geomapping_matrix',
#                 'kind': 'indices',
#                 'matrix': 'inv_geomapping_matrix',
#                 'mediatype': 'application/octet-stream',
#                 'name': 'asphalt_inventory_geomapping_matrix.indices',
#                 'nrows': 36,
#                 'path': 'asphalt_inventory_geomapping_matrix.indices.npy',
#                 'profile': 'data-resource'},
#                {'category': 'vector',
#                 'format': 'npy',
#                 'group': 'asphalt_inventory_geomapping_matrix',
#                 'kind': 'data',
#                 'matrix': 'inv_geomapping_matrix',
#                 'mediatype': 'application/octet-stream',
#                 'name': 'asphalt_inventory_geomapping_matrix.data',
#                 'nrows': 36,
#                 'path': 'asphalt_inventory_geomapping_matrix.data.npy',
#                 'profile': 'data-resource'},
#                {'category': 'vector',
#                 'format': 'npy',
#                 'group': 'asphalt_biosphere_matrix',
#                 'kind': 'indices',
#                 'matrix': 'biosphere_matrix',
#                 'mediatype': 'application/octet-stream',
#                 'name': 'asphalt_biosphere_matrix.indices',
#                 'nrows': 6,
#                 'path': 'asphalt_biosphere_matrix.indices.npy',
#                 'profile': 'data-resource'},
#                {'category': 'vector',
#                 'format': 'npy',
#                 'group': 'asphalt_biosphere_matrix',
#                 'kind': 'data',
#                 'matrix': 'biosphere_matrix',
#                 'mediatype': 'application/octet-stream',
#                 'name': 'asphalt_biosphere_matrix.data',
#                 'nrows': 6,
#                 'path': 'asphalt_biosphere_matrix.data.npy',
#                 'profile': 'data-resource'},
#                {'category': 'vector',
#                 'format': 'npy',
#                 'group': 'asphalt_technosphere_matrix',
#                 'kind': 'indices',
#                 'matrix': 'technosphere_matrix',
#                 'mediatype': 'application/octet-stream',
#                 'name': 'asphalt_technosphere_matrix.indices',
#                 'nrows': 179,
#                 'path': 'asphalt_technosphere_matrix.indices.npy',
#                 'profile': 'data-resource'},
#                {'category': 'vector',
#                 'format': 'npy',
#                 'group': 'asphalt_technosphere_matrix',
#                 'kind': 'data',
#                 'matrix': 'technosphere_matrix',
#                 'mediatype': 'application/octet-stream',
#                 'name': 'asphalt_technosphere_matrix.data',
#                 'nrows': 179,
#                 'path': 'asphalt_technosphere_matrix.data.npy',
#                 'profile': 'data-resource'},
#                {'category': 'vector',
#                 'format': 'npy',
#                 'group': 'asphalt_technosphere_matrix',
#                 'kind': 'distributions',
#                 'matrix': 'technosphere_matrix',
#                 'mediatype': 'application/octet-stream',
#                 'name': 'asphalt_technosphere_matrix.distributions',
#                 'nrows': 179,
#                 'path': 'asphalt_technosphere_matrix.distributions.npy',
#                 'profile': 'data-resource'},
#                {'category': 'vector',
#                 'format': 'npy',
#                 'group': 'asphalt_technosphere_matrix',
#                 'kind': 'flip',
#                 'matrix': 'technosphere_matrix',
#                 'mediatype': 'application/octet-stream',
#                 'name': 'asphalt_technosphere_matrix.flip',
#                 'nrows': 179,
#                 'path': 'asphalt_technosphere_matrix.flip.npy',
#                 'profile': 'data-resource'}],
#  'seed': None,
#  'sequential': False,
#  'sum_inter_duplicates': False,
#  'sum_intra_duplicates': True}

# %%
dp_correlated = bwp.create_datapackage(sequential=True)

# %%
samples_indices = [coord for coord in coords_samples_map.keys()]
pprint(samples_indices)
# Out:
# [(25975, 25987),
#  (8553, 25987),
#  (25976, 25987),
#  (17503, 25987),
#  (25974, 25987),
#  (25977, 25987),
#  (25976, 25988),
#  (18370, 25990),
#  (10822, 25991),
#  (9408, 25991),
#  (18370, 25991),
#  (9408, 25992),
#  (18370, 25992),
#  (9408, 25993),
#  (18370, 25993),
#  (18370, 25994),
#  (18370, 25995),
#  (25065, 25996),
#  (20515, 25996),
#  (18987, 25996),
#  (16115, 25997),
#  (8986, 25997),
#  (25948, 25998),
#  (25949, 26002),
#  (16115, 26003),
#  (8986, 26003),
#  (18987, 26005),
#  (18987, 26006)]

# %%
# Prepare the data_array, it must be an array of arrays
samples_values = np.array([coords_samples_map[coord] for coord in samples_indices])
pprint(samples_values)
# Out:
# array([[0.29996745, 0.32703866, 0.30015698, ..., 0.3049856 , 0.30737276,
#         0.29226108],
#        [0.0425576 , 0.03969113, 0.04069381, ..., 0.04056687, 0.03873746,
#         0.04120409],
#        [0.59119169, 0.57735947, 0.57916985, ..., 0.58078443, 0.56440685,
#         0.59239116],
#        ...,
#        [0.01187474, 0.00758516, 0.00791365, ..., 0.01155531, 0.01935971,
#         0.00464268],
#        [0.00600252, 0.00600731, 0.00588028, ..., 0.0056302 , 0.00624567,
#         0.00604022],
#        [0.00545812, 0.00620634, 0.00601627, ..., 0.00585346, 0.00552031,
#         0.00553195]])

# %%
dp_correlated.add_persistent_array(
    matrix="technosphere_matrix",
    indices_array=np.array(samples_indices, dtype=bwp.INDICES_DTYPE),
    data_array=samples_values,
    # We flip the signs of the samples
    # to obey bw's convention
    flip_array=np.array([True for _ in range(len(samples_values))]),
)

# %% [markdown]
# ### Build the new data objects to re-do the LCA

# %%
data_objs.append(dp_correlated)

# %%
dp_lca = bc.LCA(demand=indexed_demand, data_objs=data_objs, use_arrays=True)
dp_lca.lci()
dp_lca.lcia()
dp_lca.score
# Out:
# 0.1824022717061968

# %%
scores = []
for _ in autonotebook.tqdm(range(50)):
    next(dp_lca)
    scores.append(dp_lca.score)
# Out:
# 100%|█████████████████████████████████████████████████████| 50/50 [04:59<00:00,  5.99s/it]

# %%
scores_a = np.array(scores)
scores_a.mean()
# Out:
# 0.16493318626543826

# %%
scores_a_s = pd.Series(scores_a)
print(scores_a_s)
# Out:
# 0     0.162284
# 1     0.157110
# 2     0.173419
# 3     0.148478
# 4     0.146166
# 5     0.194811
# 6     0.155000
# 7     0.147701
# 8     0.200901
# 9     0.186095
# 10    0.148647
# 11    0.203662
# 12    0.178047
# 13    0.197044
# 14    0.158938
# 15    0.181784
# 16    0.198502
# 17    0.171664
# 18    0.150360
# 19    0.150826
# 20    0.169061
# 21    0.135195
# 22    0.141358
# 23    0.186688
# 24    0.140305
# 25    0.119402
# 26    0.194544
# 27    0.137925
# 28    0.150871
# 29    0.163052
# 30    0.166977
# 31    0.192874
# 32    0.149546
# 33    0.134772
# 34    0.220602
# 35    0.131615
# 36    0.162099
# 37    0.208634
# 38    0.152460
# 39    0.150171
# 40    0.129086
# 41    0.134996
# 42    0.171125
# 43    0.184029
# 44    0.148167
# 45    0.281251
# 46    0.141841
# 47    0.125202
# 48    0.164808
# 49    0.146567
# dtype: float64

# %%
scores_a_s.describe()
# Out:
# count    50.000000
# mean      0.164933
# std       0.029402
# min       0.119402
# 25%       0.146850
# 50%       0.158024
# 75%       0.183468
# max       0.281251
# dtype: float64
